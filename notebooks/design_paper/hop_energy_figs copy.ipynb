# %%
import numpy as np
import pandas as pd
import yaml
import os

"""
Loading data for processing.
8 experiment conditions with (potentially) multiple trials per condition,
each trial is in it's own subdirectory
each trial has data split into multiple files
    - experiment_config.yaml
    - hardware_config.yaml
    - energy.csv
    - hop_{i}.csv

Placing trials of each condition into a dictionary as:
conditions = {
    condition_string : [
        {
            'experiment_config': experiment config dictionary from yaml,
            'hardware_config': hardware config dictionary from yaml,
            'energy': energy data in Pandas Dataframe from csv,
            'hops' : [Pandas Dataframe per hop csv file]
        }, ... , repeat for each trial
    ]
}
"""


directory = r'C:\Users\Joseph Sullivan\Documents\hsa_hopper_control\data\2_29_25\use'
# directory = r'C:\Users\Joseph Sullivan\Documents\hsa_hopper_control\data\hop_experiments\design_paper'
condition_strings = os.listdir(directory)
conditions = {}
for cond in condition_strings:
    cond_path = os.path.join(directory, cond)
    trial_folders = os.listdir(cond_path)
    trials = []
    for tf in trial_folders:
        trial_path = os.path.join(cond_path, tf)
        with open(os.path.join(trial_path, 'experiment_config.yaml')) as f: 
            exp_config = yaml.load(f, yaml.Loader)
        with open(os.path.join(trial_path, 'hardware_config.yaml')) as f: 
            hard_config = yaml.load(f, yaml.Loader)
        # energy = pd.read_csv(os.path.join(trial_path, 'energy.csv'))
        hop_files = [hf for hf in os.listdir(trial_path) if 'hop' in hf]
        hops = [None]*len(hop_files)
        for hf in hop_files:
            parts = os.path.splitext(hf)
            file_idx = int((parts[0].split('_'))[-1])
            hop_path = os.path.join(trial_path, hf)
            df = pd.read_csv(os.path.join(trial_path, hf))
            df['file_idx'] = len(df)*file_idx
            hops[file_idx] = df

        data = pd.concat(hops, ignore_index=True)
        trials.append({
            'experiment_config' : exp_config,
            'hardware_config' : hard_config,
            'data' : data
        })
        conditions[cond] = trials

# %%
""" How to fucking do data segmentation ?"""

from hsa_hopper.kinematics import KinematicParameters, forward_kinematics
from hsa_hopper.collocation import interp_covector, diff_tensor, interp_tensor
from hsa_hopper.controller import HopController

""" We need to, as accurately as possible, isolate the touch-down time.
    This occurs shortly before the controller mode switches from flight to stance0.

    Probably best to do the data filtering now, rather than after segmentation.
    Then I can add a "hop index" column to the data frames once segmentation is figured out.
"""

""" So we are filtering then. """

# trials = conditions['hsa_1900g']
for condition, trials in conditions.items():
    for trial in trials:
        # model parameters
        kin_params = trial['hardware_config']['kinematics']
        params = KinematicParameters(kin_params['a'],kin_params['b'],kin_params['c'],kin_params['d'])
        total_mass = float(trial['experiment_config']['mass'])/1e3

        # raw data
        df = trial['data']
        x_raw = df['x_rad'].to_numpy()
        # y_raw = forward_kinematics(params, x_raw)[0]
        t_s = df['t_s'].to_numpy()
        tau_raw = df['torque'].to_numpy()

        # output arrays
        x = np.zeros_like(x_raw)
        xdot = np.zeros_like(x)
        xddot = np.zeros_like(x)

        # y = np.zeros_like(y_raw)
        # ydot = np.zeros_like(y)
        # yddot = np.zeros_like(y)

        tau = np.zeros_like(tau_raw)
        
        # savgol filtering params
        degree = 2
        window = 7

        # savgol filtering loop
        N_timestamps = t_s.size
        for i in range(N_timestamps):
            start_idx = max(0,i-window//2)
            stop_idx = min(N_timestamps,start_idx+window)
            A = np.vstack(
                [interp_covector(t_s[j],t_s[start_idx],t_s[stop_idx-1],degree+1)
                    for j in range(start_idx,stop_idx)]
            )
            t_eval = interp_covector(t_s[i],t_s[start_idx],t_s[stop_idx-1],degree+1)
            dt = diff_tensor(t_s[start_idx], t_s[stop_idx-1], degree+1)

            x_coeffs, res, rank, s = np.linalg.lstsq(A,x_raw[start_idx:stop_idx],rcond=None)
            x[i] = np.dot(t_eval, x_coeffs)[0]
            xdot[i] = np.dot(t_eval, dt@x_coeffs)[0]
            xddot[i] = np.dot(t_eval, dt@(dt@x_coeffs))[0]

            A = np.vstack(
                [interp_covector(t_s[j],t_s[start_idx],t_s[stop_idx-1],degree-1)
                    for j in range(start_idx, stop_idx)]
            )
            t_eval = interp_covector(t_s[i],t_s[start_idx],t_s[stop_idx-1],degree-1)
            tau_coeffs, res, rank, s = np.linalg.lstsq(A,tau_raw[start_idx:stop_idx],rcond=None)
            tau[i] = np.dot(t_eval, tau_coeffs)[0]

        fk,jac,hess = forward_kinematics(params, x, jacobian=True, hessian=True)
        df['x_rad'] = x
        df['xdot'] = xdot
        df['xddot'] = xddot
        df['y_m'] = fk[0]
        df['ydot'] = jac[0]*xdot
        df['yddot'] = jac[0]*xddot + hess[0]*xdot**2
        df['torque'] = tau
        df['dydx'] = jac[0]
        df['d2yd2x'] = hess[0]
        trial['data'] = df

# %%
"""
Looks like I can use the yddot estimates to determine the stance time, by taking slices based on the file index,
and then finding the timestamp where yddot is minimal.
"""

for cond, trials in conditions.items():
    for trial in trials:
        df = trial['data']
        file_indices = df['file_idx'].unique()

        # add a new column for the hop index
        df['hop_idx'] = len(df)*[-1]

        last_frame = df['file_idx'] == file_indices[0]

        last_td_idx = df.loc[last_frame,'yddot'].idxmin()-2
        ALL_STANCE0 = df['mode'] == HopController._STANCE0
        for i in range(1,len(file_indices)-1):

            # get frame index of min yddot in this dataframe
            this_frame = df['file_idx'] == file_indices[i]
            next_td_idx = df.loc[this_frame,'yddot'].idxmin()-2

            # change mode to reflect correction
            stance_frame = this_frame & ALL_STANCE0
            stance0_idx = df.loc[stance_frame, 'mode'].idxmin()
            df.loc[last_td_idx:stance0_idx, 'mode'] = HopController._STANCE0

            # set hop_idx at last_td_idx:next_td_idx to i-1
            df.loc[last_td_idx:next_td_idx, 'hop_idx'] = i-1


            # update last_frame and last_td_idx
            last_frame = this_frame
            last_td_idx = next_td_idx 

        # drop rows with hop_idx = -1
        trial['data'] = df[df['hop_idx'] != -1]

# %%
from matplotlib import pyplot as plt
cond = 'hsa_1500g'
trials = conditions[cond]
df = trials[0]['data']
for hop in df['hop_idx'].unique():
    frame = df['hop_idx'] == hop
    t = df.loc[frame, 't_s'].to_numpy()
    tau = df.loc[frame, 'torque'].to_numpy()
    x = df.loc[frame, 'x_rad'].to_numpy()
    y = df.loc[frame, 'y_m'].to_numpy()
    ydot = df.loc[frame, 'ydot'].to_numpy()
    xdot = df.loc[frame, 'xdot'].to_numpy()
    xddot = df.loc[frame, 'xddot'].to_numpy()
    mode = df.loc[frame, 'mode'].to_numpy()
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(8,6))

i_stance1 = next(i for i in range(len(mode)) if mode[i] == HopController._STANCE1)
i_flight = next(i for i in range(len(mode)) if mode[i] == HopController._FLIGHT)
t = t-t[0]
axs[0,0].set_title('Leg Length')
axs[0,0].plot(t, 100*y, color='black')
axs[0,0].axvspan(t[0], t[i_stance1], alpha=.2, color='C3')
axs[0,0].axvspan(t[i_stance1], t[i_flight], alpha=.2, color='C4')
axs[0,0].set_xlabel('Time (s)')
axs[0,0].set_ylabel('Centimeters')

axs[0,1].set_title('Leg Velocity')
axs[0,1].plot(t, ydot, color='black')
axs[0,1].axvspan(t[0], t[i_stance1], alpha=.2, color='C3')
axs[0,1].axvspan(t[i_stance1], t[i_flight], alpha=.2, color='C4')
axs[0,1].set_xlabel('Time (s)')
axs[0,1].set_ylabel('Meters per second')

axs[1,0].set_title('Leg Motor Torque')
axs[1,0].plot(t, tau, color='black')
axs[1,0].axvspan(t[0], t[i_stance1], alpha=.2, color='C3')
axs[1,0].axvspan(t[i_stance1], t[i_flight], alpha=.2, color='C4')
axs[1,0].set_xlabel('Time (s)')
axs[1,0].set_ylabel('Newton Meters')

axs[1,1].set_title('Leg Motor Power')
axs[1,1].plot(t, tau*xdot, color='black')
axs[1,1].axvspan(t[0], t[i_stance1], alpha=.2, color='C3')
axs[1,1].axvspan(t[i_stance1], t[i_flight], alpha=.2, color='C4')
axs[1,1].set_xlabel('Time (s)')
axs[1,1].set_ylabel('Watts')
fig.tight_layout()
fig.savefig('exmaple_trajectory.png', dpi=900)
# plt.plot(t-t[0],100*y)
# plt.plot(t-t[0],tau)

# %%
"""
drop any incomplete hops from data frames
"""
for cond, trials in conditions.items():
    for trial in trials:
        df = trial['data']
        hop_indices = df['hop_idx'].unique()
        for idx in hop_indices:
            hop_frame = df['hop_idx'] == idx
            modes = df.loc[hop_frame, 'mode'].unique()
            if HopController._STANCE0 not in modes:
                df.loc[hop_frame, 'hop_idx'] = -1
            if HopController._STANCE1 not in modes:
                df.loc[hop_frame, 'hop_idx'] = -1
            if HopController._FLIGHT not in modes:
                df.loc[hop_frame, 'hop_idx'] = -1
            t = df.loc[hop_frame, 't_s']
        trial['data'] = df[df['hop_idx'] != -1]

# %%
# Now that we have that segmented the data better, we can do work calculations with a more detailed inertial model
J = 3.5e-3                # motor inertia (approx)
m_foot = 0.
m_cart = 1.3-m_foot
R = 3*.095              # motor effective resistance
Kv = 105*(2*np.pi/60)/6 # motor constant from datasheet (Volts*s/rad)
Kt = 1/Kv               # motor constant in Nm/A
Kfudge = .78            # QDD torque model factor

for cond, trials in conditions.items():
    for trial_idx, trial in enumerate(trials):
        summary = {
            'HSA' : [],
            'Mass': [],
            'Hop Height' : [],
            'Max Leg Length': [],
            'Min Leg Length': [],
            'Period' : [],
            'Electrical Loss': [],
            'Thermal Loss': [],
            'Stance Positive Motor Work': [],
            'Stance Negative Motor Work': [],
            'Positive Motor Work': [],
            'Negative Motor Work': [],
            'Stance Positive Joint Work': [],
            'Stance Negative Joint Work': [],
            'Positive Joint Work': [],
            'Negative Joint Work': [],
            'Trial Index' : trial_idx,
        }
        df = trial['data']
        m_weight = trial['experiment_config']['mass']/1000-1.3
        ALL_STANCE0 = df['mode'] == HopController._STANCE0
        ALL_STANCE1 = df['mode'] == HopController._STANCE1
        ALL_STANCE = ALL_STANCE0 | ALL_STANCE1
        ALL_FLIGHT = df['mode'] == HopController._FLIGHT
        hop_indices = df['hop_idx'].unique()
        for hop_idx in hop_indices:
            hop_frame = df['hop_idx'] == hop_idx
            stance_frame = hop_frame & ALL_STANCE
            flight_frame = hop_frame & ALL_FLIGHT

            # get relevant data
            t = df.loc[hop_frame, 't_s'].to_numpy()
            x = df.loc[hop_frame,'x_rad'].to_numpy()
            xdot = df.loc[hop_frame,'xdot'].to_numpy()
            xddot = df.loc[hop_frame,'xddot'].to_numpy()
            y = df.loc[hop_frame,'y_m'].to_numpy()
            ydot = df.loc[hop_frame,'ydot'].to_numpy()
            yddot = df.loc[hop_frame,'yddot'].to_numpy()
            tau = df.loc[hop_frame, 'torque'].to_numpy()
            mode = df.loc[hop_frame, 'mode'].to_numpy()

            flight_start = next(i for i in range(x.size) if mode[i] == HopController._FLIGHT)

            # pull back a couple flight indices into the stance index
            therm_power = R*(tau[:flight_start]/(Kt*Kfudge))**2
            motor_power = tau[:flight_start] * xdot[:flight_start]
            joint_power = (J*xddot[:flight_start])*xdot[:flight_start] + ((m_cart+m_weight)*(yddot+9.81)[:flight_start])*ydot[:flight_start]

            stance_therm_loss= np.trapz(therm_power, x=t[:flight_start])
            stance_pos_motor_work = np.trapz(np.clip(motor_power, 0, np.inf), x=t[:flight_start])
            stance_neg_motor_work = np.trapz(np.clip(motor_power, -np.inf, 0), x=t[:flight_start])
            stance_pos_joint_work = np.trapz(np.clip(joint_power, 0, np.inf), x=t[:flight_start])
            stance_neg_joint_work = np.trapz(np.clip(joint_power, -np.inf, 0), x=t[:flight_start])

            print(f'{cond}, hop_idx={hop_idx}')
            print('Stance work:')
            print(f'Thermal loss: {stance_therm_loss}')
            print(f'Motor work: {(stance_pos_motor_work, stance_neg_motor_work)}')
            print(f'Joint work: {(stance_pos_joint_work, stance_neg_joint_work)}')

            # print(stance_pos_motor_work + stance_neg_motor_work)
            # print(stance_pos_joint_work + stance_neg_joint_work)
            xdot_initial = xdot[0]
            xdot_final = xdot[flight_start]
            y_initial = y[0]
            y_final = y[flight_start]
            ydot_initial = ydot[0]
            ydot_final = ydot[flight_start]
            y_min = np.min(y[:flight_start])
            h = (ydot_final**2)/(2*9.81)

            therm_power = R*(tau[flight_start:]/(Kt*Kfudge))**2
            motor_power = tau[flight_start:] * xdot[flight_start:]
            joint_power = (J*xddot[flight_start:])*xdot[flight_start:] + (m_foot*yddot[flight_start:])*ydot[flight_start:]

            flight_therm_loss= np.trapz(therm_power, x=t[flight_start:])
            flight_pos_motor_work = np.trapz(np.clip(motor_power, 0, np.inf), x=t[flight_start:])
            flight_neg_motor_work = np.trapz(np.clip(motor_power, -np.inf, 0), x=t[flight_start:])
            flight_pos_joint_work = np.trapz(np.clip(joint_power, 0, np.inf), x=t[flight_start:])
            flight_neg_joint_work = np.trapz(np.clip(joint_power, -np.inf, 0), x=t[flight_start:])
            print('Flight work:')
            print(f'Thermal loss: {flight_therm_loss}')
            print(f'Motor work: {(flight_pos_motor_work, flight_neg_motor_work)}')
            print(f'Joint work: {(flight_pos_joint_work, flight_neg_joint_work)}')

            print('Total:')
            total_therm_loss = stance_therm_loss + flight_therm_loss
            print(f'Thermal loss: {total_therm_loss}')
            total_pos_motor_work = stance_pos_motor_work + flight_pos_motor_work
            total_neg_motor_work = stance_neg_motor_work + flight_neg_motor_work
            print(f'Motor work: {total_pos_motor_work + total_neg_motor_work}')
            total_pos_joint_work = stance_pos_joint_work + flight_pos_joint_work
            total_neg_joint_work = stance_neg_joint_work + flight_neg_joint_work

            print("\n")
            print(f'Hop Height: {100*h}')
            print(f'Joint work: {total_pos_joint_work + total_neg_joint_work}')
            hop_energy = h*(m_cart+m_weight)*9.81
            print(f'Hop Energy: {h*(m_cart+m_weight)*9.81}')
            electric_cost = total_pos_motor_work+total_neg_motor_work+total_therm_loss
            print(f'Electrical Efficiency: {hop_energy/electric_cost}')
            T = t[-1]-t[0]
            VCOT = (total_pos_motor_work+total_therm_loss) * T / ((m_cart+m_weight)*9.81*h)
            print(f'Vertical Cost of Transport: {VCOT}')
            print(f'Passive Efficiency: {1-total_pos_motor_work/total_pos_joint_work}')
            print("\n")

            summary['HSA'].append(cond[0:3] == 'hsa')
            summary['Mass'].append(trial['experiment_config']['mass']/1000)
            summary['Hop Height'].append(h)
            summary['Min Leg Length'].append(y_min)
            summary['Max Leg Length'].append(np.max(y[:flight_start]))
            summary['Period'].append(t[-1]-t[0])
            summary['Electrical Loss'].append(electric_cost)
            summary['Thermal Loss'].append(total_therm_loss)
            summary['Stance Positive Motor Work'].append(stance_pos_motor_work)
            summary['Stance Negative Motor Work'].append(stance_neg_motor_work)
            summary['Positive Motor Work'].append(total_pos_motor_work)
            summary['Negative Motor Work'].append(total_neg_motor_work)
            summary['Stance Positive Joint Work'].append(stance_pos_joint_work)
            summary['Stance Negative Joint Work'].append(stance_neg_joint_work)
            summary['Positive Joint Work'].append(total_pos_joint_work)
            summary['Negative Joint Work'].append(total_neg_joint_work)
        trial['hop_summary'] = pd.DataFrame(summary)

summary_df = pd.concat([trial['hop_summary'] for cond, trials in conditions.items() for trial in trials])
# Out:
# hsa_1300g, hop_idx=0
# Stance work:
# Thermal loss: 0.6092226634694972
# Motor work: (1.49422791041945, -0.0739135006848055)
# Joint work: (1.9122605652162927, -0.9050732405413291)
# Flight work:
# Thermal loss: 0.026097174973796117
# Motor work: (0.06763211410176546, -0.16239726210033784)
# Joint work: (0.05043257294011421, -0.39820096331803095)
# Total:
# Thermal loss: 0.6353198384432933
# Motor work: 1.3255492617360722
#
#
# Hop Height: 5.190216887700828
# Joint work: 0.6594189342970469
# Hop Energy: 0.6619083596884866
# Electrical Efficiency: 0.33755866703592824
# Vertical Cost of Transport: 1.1909216529223177
# Passive Efficiency: 0.204226073777229
#
#
# hsa_1300g, hop_idx=1
# Stance work:
# Thermal loss: 0.584637471932414
# Motor work: (1.5078095134056484, -0.08478087310909557)
# Joint work: (1.9872328945469517, -0.9466295290305948)
# Flight work:
# Thermal loss: 0.026395291802759742
# Motor work: (0.07074850673538315, -0.16144803479639716)
# Joint work: (0.048655857232362223, -0.40032936060867474)
# Total:
# Thermal loss: 0.6110327637351738
# Motor work: 1.332329112235539
#
#
# Hop Height: 5.264481643221588
# Joint work: 0.6889298621400441
# Hop Energy: 0.6713793439600492
# Electrical Efficiency: 0.3454731474675523
# Vertical Cost of Transport: 1.174489940867805
# Passive Efficiency: 0.22463444097256646
#
#
# hsa_1300g, hop_idx=2
# Stance work:
# Thermal loss: 0.6108862901408901
# Motor work: (1.5378363813266396, -0.08244570371397837)
# Joint work: (2.003012315705227, -0.981747565313756)
# Flight work:
# Thermal loss: 0.025904593794029776
# Motor work: (0.06772652337890395, -0.16242292251933074)
# Joint work: (0.04639388104469426, -0.40301461757308565)
# Total:
# Thermal loss: 0.6367908839349199
# Motor work: 1.3606942784722345
#
#
# Hop Height: 5.349226133503266
# Joint work: 0.6646440138630796
# Hop Energy: 0.6821868088056715
# Electrical Efficiency: 0.3415228416433258
# Vertical Cost of Transport: 1.1863808025270486
# Passive Efficiency: 0.21657165512051857
#
#
# hsa_1300g, hop_idx=3
# Stance work:
# Thermal loss: 0.6088650913991789
# Motor work: (1.5204689840998284, -0.08726122264643696)
# Joint work: (2.0183833136427354, -1.000502030558305)
# Flight work:
# Thermal loss: 0.026186867524314494
# Motor work: (0.0710054247895236, -0.16306101730662698)
# Joint work: (0.0483501937298147, -0.3968567306439499)
# Total:
# Thermal loss: 0.6350519589234934
# Motor work: 1.3411521689362882
#
#
# Hop Height: 5.3044076885106985
# Joint work: 0.669374746170295
# Hop Energy: 0.6764711125157694
# Electrical Efficiency: 0.3423083187506465
# Vertical Cost of Transport: 1.1975565672885453
# Passive Efficiency: 0.22995664258978288
#
#
# hsa_1300g, hop_idx=4
# Stance work:
# Thermal loss: 0.6311574599887381
# Motor work: (1.5899988363012765, -0.09025759991033516)
# Joint work: (2.0267422226106735, -0.990175209662975)
# Flight work:
# Thermal loss: 0.025390857513575
# Motor work: (0.06705647485011236, -0.1647544850300735)
# Joint work: (0.051976350306988495, -0.418985940416468)
# Total:
# Thermal loss: 0.656548317502313
# Motor work: 1.40204322621098
#
#
# Hop Height: 5.412009353827988
# Joint work: 0.6695574228382191
# Hop Energy: 0.6901935528936833
# Electrical Efficiency: 0.33527464688245556
# Vertical Cost of Transport: 1.2160990656764108
# Passive Efficiency: 0.2028476905242792
#
#
# hsa_1300g, hop_idx=5
# Stance work:
# Thermal loss: 0.6201766788699402
# Motor work: (1.5780114098015543, -0.09104140072659317)
# Joint work: (2.0739074023201405, -1.0142929888496384)
# Flight work:
# Thermal loss: 0.025628456328136644
# Motor work: (0.07055024755994219, -0.15930418434510407)
# Joint work: (0.05397833385907929, -0.41906283629291935)
# Total:
# Thermal loss: 0.6458051351980768
# Motor work: 1.3982160722897992
#
#
# Hop Height: 5.444261548282447
# Joint work: 0.6945299110366621
# Hop Energy: 0.6943066752524605
# Electrical Efficiency: 0.33967684518585345
# Vertical Cost of Transport: 1.2092963191499664
# Passive Efficiency: 0.22525837297936213
#
#
# hsa_1300g, hop_idx=6
# Stance work:
# Thermal loss: 0.613321014042459
# Motor work: (1.5804340394910315, -0.08605348694971768)
# Joint work: (2.0789310239593077, -1.0151016572049358)
# Flight work:
# Thermal loss: 0.026249743486316323
# Motor work: (0.07015857040621232, -0.1644676164499958)
# Joint work: (0.05086848056650177, -0.42766974246994177)
# Total:
# Thermal loss: 0.6395707575287753
# Motor work: 1.4000715064975304
#
#
# Hop Height: 5.590146776528087
# Joint work: 0.6870281048509317
# Hop Energy: 0.712911418410627
# Electrical Efficiency: 0.34952767501655985
# Vertical Cost of Transport: 1.1716092654635741
# Passive Efficiency: 0.22500094192446474
#
#
# hsa_1300g, hop_idx=7
# Stance work:
# Thermal loss: 0.6224561870924051
# Motor work: (1.5631421741055624, -0.09471228330348744)
# Joint work: (2.0459314864240783, -1.020657814646413)
# Flight work:
# Thermal loss: 0.027277234543552395
# Motor work: (0.06996815606407983, -0.17017412610481616)
# Joint work: (0.048946905624000885, -0.406127130828434)
# Total:
# Thermal loss: 0.6497334216359575
# Motor work: 1.3682239207613387
#
#
# Hop Height: 5.35139312892658
# Joint work: 0.6680934465732324
# Hop Energy: 0.6824631657320069
# Electrical Efficiency: 0.3381950407937034
# Vertical Cost of Transport: 1.2164228369199366
# Passive Efficiency: 0.22042714442578437
#
#
# hsa_1300g, hop_idx=8
# Stance work:
# Thermal loss: 0.6239369247886943
# Motor work: (1.5713095771669523, -0.09447865802227208)
# Joint work: (2.0292815013230086, -0.9888117759719547)
# Flight work:
# Thermal loss: 0.0262854436390838
# Motor work: (0.06942237745306501, -0.16530394983197827)
# Joint work: (0.05218097836435526, -0.41557508100096496)
# Total:
# Thermal loss: 0.6502223684277781
# Motor work: 1.380949346765767
#
#
# Hop Height: 5.429339844040086
# Joint work: 0.6770756227144441
# Hop Energy: 0.6924037103104322
# Electrical Efficiency: 0.34088881069538474
# Vertical Cost of Transport: 1.21066712793504
# Passive Efficiency: 0.2117407973328177
#
#
# hsa_1300g, hop_idx=9
# Stance work:
# Thermal loss: 0.6208146056937723
# Motor work: (1.5759303932410667, -0.09267553663336382)
# Joint work: (2.0461070438986426, -0.9984451268018018)
# Flight work:
# Thermal loss: 0.02465765367755188
# Motor work: (0.0654705664819414, -0.16220412997064673)
# Joint work: (0.05208383252439382, -0.4165194420061732)
# Total:
# Thermal loss: 0.6454722593713242
# Motor work: 1.3865212931189976
#
#
# Hop Height: 5.418683101912144
# Joint work: 0.6832263076150618
# Hop Energy: 0.6910446559868558
# Electrical Efficiency: 0.3400821105657259
# Vertical Cost of Transport: 1.2072318181688877
# Passive Efficiency: 0.21770655941405903
#
#
# hsa_1300g, hop_idx=10
# Stance work:
# Thermal loss: 0.6233662833230502
# Motor work: (1.5761396856700554, -0.09179738602009552)
# Joint work: (2.048216683104047, -1.0126413963377008)
# Flight work:
# Thermal loss: 0.026467764483744067
# Motor work: (0.06642935383651588, -0.1675899089255018)
# Joint work: (0.053281014754902406, -0.4115370322929405)
# Total:
# Thermal loss: 0.6498340478067943
# Motor work: 1.383181744560974
#
#
# Hop Height: 5.362524899715651
# Joint work: 0.6773192692283083
# Hop Energy: 0.683882800460737
# Electrical Efficiency: 0.33638833649405514
# Vertical Cost of Transport: 1.2306373670577229
# Passive Efficiency: 0.21838170882601704
#
#
# hsa_1300g, hop_idx=11
# Stance work:
# Thermal loss: 0.6255471621322013
# Motor work: (1.5791775481398822, -0.08704412363378296)
# Joint work: (2.0060226394458254, -1.0082967860358723)
# Flight work:
# Thermal loss: 0.025567661664799065
# Motor work: (0.07107630134029592, -0.1588171888010055)
# Joint work: (0.04688326089354648, -0.40648708128771416)
# Total:
# Thermal loss: 0.6511148237970004
# Motor work: 1.4043925370453896
#
#
# Hop Height: 5.377615762171498
# Joint work: 0.6381220330157855
# Hop Energy: 0.6858073381497312
# Electrical Efficiency: 0.33364382498181516
# Vertical Cost of Transport: 1.1997439612972451
# Passive Efficiency: 0.19613760708302808
#
#
# hsa_1300g, hop_idx=12
# Stance work:
# Thermal loss: 0.5972020083896886
# Motor work: (1.3860865168788645, -0.07437623603914109)
# Joint work: (1.5982984560614644, -0.7230050624996671)
# Flight work:
# Thermal loss: 0.02392125295368012
# Motor work: (0.06794065812462394, -0.14445223836336107)
# Joint work: (0.03979452966518699, -0.36046008453104367)
# Total:
# Thermal loss: 0.6211232613433687
# Motor work: 1.2351987006009864
#
#
# Hop Height: 4.8428573390485
# Joint work: 0.5546278386959405
# Hop Energy: 0.6176095964488553
# Electrical Efficiency: 0.3327060763758656
# Vertical Cost of Transport: 1.2138865258591454
# Passive Efficiency: 0.11236591104839622
#
#
# hsa_1300g, hop_idx=13
# Stance work:
# Thermal loss: 0.6145794822490898
# Motor work: (1.50675427069141, -0.08533352853380832)
# Joint work: (1.8974300789082608, -0.9436466475155026)
# Flight work:
# Thermal loss: 0.025137677957471682
# Motor work: (0.0703073236455764, -0.1557982875380755)
# Joint work: (0.04748724317306123, -0.39065780675845185)
# Total:
# Thermal loss: 0.6397171602065614
# Motor work: 1.3359297782651027
#
#
# Hop Height: 5.173208086136693
# Joint work: 0.6106128678073677
# Hop Energy: 0.6597392272250125
# Electrical Efficiency: 0.3339357930700809
# Vertical Cost of Transport: 1.217860569663088
# Passive Efficiency: 0.18913694868565445
#
#
# hsa_1300g, hop_idx=14
# Stance work:
# Thermal loss: 0.6239634836941519
# Motor work: (1.538460413782273, -0.08064462906223399)
# Joint work: (1.9594601953954331, -0.961442702768488)
# Flight work:
# Thermal loss: 0.025128738777170347
# Motor work: (0.06647912822474399, -0.15829758813527625)
# Joint work: (0.046071244965615016, -0.3918908033288397)
# Total:
# Thermal loss: 0.6490922224713223
# Motor work: 1.3659973248095068
#
#
# Hop Height: 5.165091205416431
# Joint work: 0.6521979342637203
# Hop Energy: 0.6587040814267574
# Electrical Efficiency: 0.3268857616355638
# Vertical Cost of Transport: 1.2391716580703134
# Passive Efficiency: 0.19974351450801198
#
#
# hsa_1300g, hop_idx=15
# Stance work:
# Thermal loss: 0.6083734196320417
# Motor work: (1.4792949160631979, -0.08615264030180464)
# Joint work: (1.882833247964412, -0.9603468266809809)
# Flight work:
# Thermal loss: 0.024963455194534412
# Motor work: (0.06520429124425135, -0.15776011799175993)
# Joint work: (0.043028669291629046, -0.3754901683572397)
# Total:
# Thermal loss: 0.6333368748265762
# Motor work: 1.3005864490138848
#
#
# Hop Height: 5.029801448173866
# Joint work: 0.5900249222178204
# Hop Energy: 0.6414505786856132
# Electrical Efficiency: 0.3316835630338205
# Vertical Cost of Transport: 1.2106124667680898
# Passive Efficiency: 0.19802183455185385
#
#
# hsa_1300g, hop_idx=16
# Stance work:
# Thermal loss: 0.6330203801138878
# Motor work: (1.5207482461979318, -0.08269917402563763)
# Joint work: (1.902851273254111, -0.9510533966049449)
# Flight work:
# Thermal loss: 0.0247610558278793
# Motor work: (0.06933865357945733, -0.1495288556970465)
# Joint work: (0.04690473658857036, -0.383224903768697)
# Total:
# Thermal loss: 0.6577814359417672
# Motor work: 1.357858870054705
#
#
# Hop Height: 5.025307355489063
# Joint work: 0.6154777094690396
# Hop Energy: 0.6408774470455202
# Electrical Efficiency: 0.31795228798458147
# Vertical Cost of Transport: 1.2705980436206856
# Passive Efficiency: 0.18446877878546075
#
#
# hsa_1300g, hop_idx=17
# Stance work:
# Thermal loss: 0.635578163022363
# Motor work: (1.535200211541988, -0.0853831272825783)
# Joint work: (1.943081222482201, -0.9700936481361817)
# Flight work:
# Thermal loss: 0.025125246582197596
# Motor work: (0.06801292360819425, -0.15387454838228343)
# Joint work: (0.045881383012024504, -0.3881441319663292)
# Total:
# Thermal loss: 0.6607034096045606
# Motor work: 1.3639554594853207
#
#
# Hop Height: 5.05547213865351
# Joint work: 0.6307248253917146
# Hop Energy: 0.6447243618424823
# Electrical Efficiency: 0.318436044553173
# Vertical Cost of Transport: 1.2583424794896676
# Passive Efficiency: 0.1939450592376475
#
#
# hsa_1300g, hop_idx=18
# Stance work:
# Thermal loss: 0.6257859891414559
# Motor work: (1.5284737609714383, -0.08390165343373396)
# Joint work: (1.9539915105150554, -0.9735727257958696)
# Flight work:
# Thermal loss: 0.025623597399463915
# Motor work: (0.06701396128217756, -0.15982937773195594)
# Joint work: (0.04664481296963837, -0.3893230943165152)
# Total:
# Thermal loss: 0.6514095865409198
# Motor work: 1.351756691087926
#
#
# Hop Height: 5.173858413062469
# Joint work: 0.6377405033723089
# Hop Energy: 0.6598221634178567
# Electrical Efficiency: 0.3293896122287413
# Vertical Cost of Transport: 1.2281357875110226
# Passive Efficiency: 0.2025098697225456
#
#
# hsa_1300g, hop_idx=19
# Stance work:
# Thermal loss: 0.6254248262493538
# Motor work: (1.5097829465385368, -0.08897322353596243)
# Joint work: (1.9038767697516374, -0.9627404610140613)
# Flight work:
# Thermal loss: 0.025521592571430985
# Motor work: (0.06604026114923967, -0.1591022682742248)
# Joint work: (0.0457921737115781, -0.38511047252778463)
# Total:
# Thermal loss: 0.6509464188207847
# Motor work: 1.3277477158775892
#
#
# Hop Height: 5.057879675376885
# Joint work: 0.6018180099213697
# Hop Energy: 0.6450313950008142
# Electrical Efficiency: 0.3259884302932655
# Vertical Cost of Transport: 1.2483541935926172
# Passive Efficiency: 0.1917483155429317
#
#
# hsa_1300g, hop_idx=20
# Stance work:
# Thermal loss: 0.6218209432768691
# Motor work: (1.5041558169451779, -0.08879716565736454)
# Joint work: (1.914573197355882, -0.9678850909945917)
# Flight work:
# Thermal loss: 0.02609186947339907
# Motor work: (0.06867864540836048, -0.15842067499642393)
# Joint work: (0.04473148905279814, -0.38256605503840035)
# Total:
# Thermal loss: 0.6479128127502681
# Motor work: 1.32561662169975
#
#
# Hop Height: 5.056383832960512
# Joint work: 0.6088535403756881
# Hop Energy: 0.6448406302174542
# Electrical Efficiency: 0.32674487593703305
# Vertical Cost of Transport: 1.247469382165237
# Passive Efficiency: 0.1972486600659975
#
#
# hsa_1300g, hop_idx=21
# Stance work:
# Thermal loss: 0.6274972767447158
# Motor work: (1.5357213817061488, -0.08340506230550018)
# Joint work: (1.94373786452438, -0.9732574491571595)
# Flight work:
# Thermal loss: 0.02541264340370214
# Motor work: (0.06870240866922363, -0.15812278769506377)
# Joint work: (0.043386023078225436, -0.39026207410055586)
# Total:
# Thermal loss: 0.6529099201484179
# Motor work: 1.3628959403748084
#
#
# Hop Height: 5.187231096724696
# Joint work: 0.6236043643448901
# Hop Energy: 0.6615275817653005
# Electrical Efficiency: 0.3281702840141526
# Vertical Cost of Transport: 1.2296612966417473
# Passive Efficiency: 0.19258995355792696
#
#
# hsa_1300g, hop_idx=22
# Stance work:
# Thermal loss: 0.629764697152774
# Motor work: (1.5288879334176886, -0.0840099425186801)
# Joint work: (1.9520674501682094, -0.9447121324137513)
# Flight work:
# Thermal loss: 0.025381851376540785
# Motor work: (0.06966947346007762, -0.15478405441731916)
# Joint work: (0.0467530120314509, -0.3928217354381314)
# Total:
# Thermal loss: 0.6551465485293148
# Motor work: 1.3597634099417668
#
#
# Hop Height: 5.105142467205723
# Joint work: 0.6612865943477777
# Hop Energy: 0.651058818842746
# Electrical Efficiency: 0.3231205524125609
# Vertical Cost of Transport: 1.2516116817777658
# Passive Efficiency: 0.20024962866420382
#
#
# hsa_1300g, hop_idx=23
# Stance work:
# Thermal loss: 0.6208652915772173
# Motor work: (1.5097702529955355, -0.09172963827725575)
# Joint work: (1.9438954996823206, -0.9804914097085597)
# Flight work:
# Thermal loss: 0.025661860608793115
# Motor work: (0.06756472203260931, -0.16085631617135945)
# Joint work: (0.04345697704027797, -0.3857389208480759)
# Total:
# Thermal loss: 0.6465271521860104
# Motor work: 1.3247490205795294
#
#
# Hop Height: 5.159306015830383
# Joint work: 0.6211221461659628
# Hop Energy: 0.6579662961988488
# Electrical Efficiency: 0.33377682198419506
# Vertical Cost of Transport: 1.2198934192044124
# Passive Efficiency: 0.2063134277874178
#
#
# hsa_1300g, hop_idx=24
# Stance work:
# Thermal loss: 0.6271525040510669
# Motor work: (1.5290999719209903, -0.09291311124087123)
# Joint work: (1.9319954842936036, -0.9635938345883859)
# Flight work:
# Thermal loss: 0.024926904971598583
# Motor work: (0.06646252016626483, -0.15626070674291712)
# Joint work: (0.045288951626022485, -0.386941088414175)
# Total:
# Thermal loss: 0.6520794090226655
# Motor work: 1.3463886741034667
#
#
# Hop Height: 5.085756105567768
# Joint work: 0.626749512917065
# Hop Energy: 0.6485864761430575
# Electrical Efficiency: 0.32454182361946804
# Vertical Cost of Transport: 1.2593144084886194
# Passive Efficiency: 0.19305363300188716
#
#
# hsa_1300g, hop_idx=25
# Stance work:
# Thermal loss: 0.632074039622696
# Motor work: (1.5510608901585266, -0.08869954966587869)
# Joint work: (1.9591219476711301, -0.9726219028382052)
# Flight work:
# Thermal loss: 0.025619193598305383
# Motor work: (0.0702218701580595, -0.156573604573164)
# Joint work: (0.04665801906341463, -0.3964433607916112)
# Total:
# Thermal loss: 0.6576932332210014
# Motor work: 1.3760096060775433
#
#
# Hop Height: 5.176137312901745
# Joint work: 0.6367147031047284
# Hop Energy: 0.6601127915143595
# Electrical Efficiency: 0.32458664990704467
# Vertical Cost of Transport: 1.2579935887155909
# Passive Efficiency: 0.19169460897743884
#
#
# hsa_1300g, hop_idx=26
# Stance work:
# Thermal loss: 0.6244445678692422
# Motor work: (1.5479997784869295, -0.08751326394650215)
# Joint work: (1.9836383105796047, -0.9799278481348257)
# Flight work:
# Thermal loss: 0.024965478858860617
# Motor work: (0.0660689530596217, -0.16068968293348548)
# Joint work: (0.046492955447688396, -0.4004574050193571)
# Total:
# Thermal loss: 0.6494100467281028
# Motor work: 1.3658657846665636
#
#
# Hop Height: 5.308057991028687
# Joint work: 0.6497460128731101
# Hop Energy: 0.6769366355958887
# Electrical Efficiency: 0.3359027211314376
# Vertical Cost of Transport: 1.2180890433131057
# Passive Efficiency: 0.204943661251483
#
#
# hsa_1300g, hop_idx=27
# Stance work:
# Thermal loss: 0.6287191101340841
# Motor work: (1.5470751094802162, -0.09031619380107589)
# Joint work: (1.9560244726262994, -0.9735640897613616)
# Flight work:
# Thermal loss: 0.025612284769167666
# Motor work: (0.07109648035960076, -0.16160053980275227)
# Joint work: (0.045331207788187375, -0.3866004872928139)
# Total:
# Thermal loss: 0.6543313949032518
# Motor work: 1.3662548562359889
#
#
# Hop Height: 5.132474612769751
# Joint work: 0.6411911033603113
# Hop Energy: 0.6545444873665264
# Electrical Efficiency: 0.3239379100978655
# Vertical Cost of Transport: 1.2594117699925491
# Passive Efficiency: 0.19146226446630976
#
#
# hsa_1300g, hop_idx=28
# Stance work:
# Thermal loss: 0.6265902407602914
# Motor work: (1.5647126453216598, -0.08955096482328648)
# Joint work: (1.9871472585347385, -0.9843077698934612)
# Flight work:
# Thermal loss: 0.026587889141914164
# Motor work: (0.06540173961855159, -0.17129941055924175)
# Joint work: (0.045360835523647024, -0.3996326491126257)
# Total:
# Thermal loss: 0.6531781299022055
# Motor work: 1.3692640095576831
#
#
# Hop Height: 5.313579820104844
# Joint work: 0.6485676750522986
# Hop Energy: 0.6776408344579707
# Electrical Efficiency: 0.33506067799741396
# Vertical Cost of Transport: 1.221001120284809
# Passive Efficiency: 0.19797889626835363
#
#
# hsa_1300g, hop_idx=29
# Stance work:
# Thermal loss: 0.6258492685877763
# Motor work: (1.5274650867060924, -0.08546704206824865)
# Joint work: (1.940678714489476, -0.970942669076226)
# Flight work:
# Thermal loss: 0.023983329123204184
# Motor work: (0.06530650815297102, -0.15588014520929114)
# Joint work: (0.04329891555586934, -0.3844838054762255)
# Total:
# Thermal loss: 0.6498325977109806
# Motor work: 1.3514244075815238
#
#
# Hop Height: 5.1423118981316795
# Joint work: 0.6285511554928938
# Hop Energy: 0.6557990363687332
# Electrical Efficiency: 0.3276935619135441
# Vertical Cost of Transport: 1.2390899073775319
# Passive Efficiency: 0.19718268455342436
#
#
# hsa_1300g, hop_idx=30
# Stance work:
# Thermal loss: 0.6204689366254469
# Motor work: (1.5332649083099057, -0.08696661832928827)
# Joint work: (1.9513799580591216, -0.9741843627349939)
# Flight work:
# Thermal loss: 0.026234334069484493
# Motor work: (0.0691944116260229, -0.16371050214204608)
# Joint work: (0.04656316614181568, -0.39764721048631413)
# Total:
# Thermal loss: 0.6467032706949314
# Motor work: 1.3517821994645942
#
#
# Hop Height: 5.242641976509684
# Joint work: 0.6261115509796293
# Hop Energy: 0.66859413126428
# Electrical Efficiency: 0.3345504089208668
# Vertical Cost of Transport: 1.2301962179791115
# Passive Efficiency: 0.19794547676284813
#
#
# hsa_1300g, hop_idx=31
# Stance work:
# Thermal loss: 0.6324785470443998
# Motor work: (1.5337501194016605, -0.09096129324015703)
# Joint work: (1.9453274622094325, -0.9795514235554319)
# Flight work:
# Thermal loss: 0.02518597056632794
# Motor work: (0.06739537787068905, -0.15912174317814992)
# Joint work: (0.040915566633869214, -0.38504520305953915)
# Total:
# Thermal loss: 0.6576645176107278
# Motor work: 1.3510624608540427
#
#
# Hop Height: 5.172335059195541
# Joint work: 0.6216464022283306
# Hop Energy: 0.6596278900992075
# Electrical Efficiency: 0.3283810578396014
# Vertical Cost of Transport: 1.2365146087566161
# Passive Efficiency: 0.19388238296056626
#
#
# hsa_1300g, hop_idx=32
# Stance work:
# Thermal loss: 0.608071810067721
# Motor work: (1.4809010510762164, -0.08566051336213301)
# Joint work: (1.8784256698285882, -0.955660283675956)
# Flight work:
# Thermal loss: 0.02519176483943735
# Motor work: (0.0677254493674859, -0.15637103779730416)
# Joint work: (0.040518215974036834, -0.37371677291869115)
# Total:
# Thermal loss: 0.6332635749071583
# Motor work: 1.3065949492842652
#
#
# Hop Height: 5.055987628048242
# Joint work: 0.5895668292079779
# Hop Energy: 0.6447901022049923
# Electrical Efficiency: 0.33239027184920883
# Vertical Cost of Transport: 1.2232712910535064
# Passive Efficiency: 0.1929797885694987
#
#
# hsa_1300g, hop_idx=33
# Stance work:
# Thermal loss: 0.6290929247580707
# Motor work: (1.5231368334039592, -0.08459415590693857)
# Joint work: (1.9060100445632093, -0.945653008808671)
# Flight work:
# Thermal loss: 0.02438086445365939
# Motor work: (0.070054391791917, -0.1497551289443423)
# Joint work: (0.04513083462870733, -0.3881243748282991)
# Total:
# Thermal loss: 0.65347378921173
# Motor work: 1.3588419403445953
#
#
# Hop Height: 5.100437165699959
# Joint work: 0.6173634955549465
# Hop Energy: 0.6504587517417159
# Electrical Efficiency: 0.3232389143452796
# Vertical Cost of Transport: 1.2481748267910535
# Passive Efficiency: 0.18345659086610333
#
#
# hsa_1300g, hop_idx=34
# Stance work:
# Thermal loss: 0.6210899964922646
# Motor work: (1.511380143484525, -0.08729040130178209)
# Joint work: (1.9118157884817526, -0.9645314947454315)
# Flight work:
# Thermal loss: 0.024481135931005687
# Motor work: (0.06444380365578238, -0.15648332117053793)
# Joint work: (0.041942445312933535, -0.38161781279681717)
# Total:
# Thermal loss: 0.6455711324232702
# Motor work: 1.3320502246679875
#
#
# Hop Height: 5.104511994645021
# Joint work: 0.6076089262524376
# Hop Energy: 0.6509784146770795
# Electrical Efficiency: 0.3291724233978527
# Vertical Cost of Transport: 1.227598068840751
# Passive Efficiency: 0.19343963859864888
#
#
# hsa_1300g, hop_idx=35
# Stance work:
# Thermal loss: 0.6226847336883642
# Motor work: (1.5140668112875666, -0.08887866119911933)
# Joint work: (1.9130650684816464, -0.9679412269968838)
# Flight work:
# Thermal loss: 0.02480091616456751
# Motor work: (0.06453036476433437, -0.16009809914150475)
# Joint work: (0.04359617457002251, -0.38330154536416144)
# Total:
# Thermal loss: 0.6474856498529317
# Motor work: 1.3296204157112768
#
#
# Hop Height: 5.078357435951284
# Joint work: 0.6054184706906236
# Hop Energy: 0.6476429238068673
# Electrical Efficiency: 0.32757115821302635
# Vertical Cost of Transport: 1.242842959303002
# Passive Efficiency: 0.19321896845573927
#
#
# hsa_1300g, hop_idx=36
# Stance work:
# Thermal loss: 0.6280676092075401
# Motor work: (1.5333155771948053, -0.0925349526379469)
# Joint work: (1.9181242178825078, -0.968443717024186)
# Flight work:
# Thermal loss: 0.024536542725164753
# Motor work: (0.06869443964098326, -0.15272789653364385)
# Joint work: (0.04468112198997522, -0.3878262560281371)
# Total:
# Thermal loss: 0.6526041519327048
# Motor work: 1.3567471676641978
#
#
# Hop Height: 5.125193285876041
# Joint work: 0.6065353668201598
# Hop Energy: 0.6536158997477717
# Electrical Efficiency: 0.3252870184388134
# Vertical Cost of Transport: 1.2588713180801125
# Passive Efficiency: 0.1838161511523777
#
#
# hsa_1300g, hop_idx=37
# Stance work:
# Thermal loss: 0.6209255716680858
# Motor work: (1.534840654974378, -0.08887307127509377)
# Joint work: (2.0161386250272106, -0.9954613496896136)
# Flight work:
# Thermal loss: 0.025299804090504887
# Motor work: (0.06791251260383808, -0.1609529169134572)
# Joint work: (0.04114254538352593, -0.3899092662836461)
# Total:
# Thermal loss: 0.6462253757585907
# Motor work: 1.3529271793896651
#
#
# Hop Height: 5.248374320702289
# Joint work: 0.671910554437477
# Hop Energy: 0.6693251771191628
# Electrical Efficiency: 0.3348044527144784
# Vertical Cost of Transport: 1.2183307118345408
# Passive Efficiency: 0.22093625770257452
#
#
# hsa_1300g, hop_idx=38
# Stance work:
# Thermal loss: 0.6271966544095178
# Motor work: (1.5384029109556883, -0.08659249415804919)
# Joint work: (1.9210941410173357, -0.9581232315782782)
# Flight work:
# Thermal loss: 0.025354475022054245
# Motor work: (0.06684510406771693, -0.16146168456147875)
# Joint work: (0.04723163620320534, -0.3964362865349212)
# Total:
# Thermal loss: 0.652551129431572
# Motor work: 1.3571938363038774
#
#
# Hop Height: 5.176416352622059
# Joint work: 0.6137662591073416
# Hop Energy: 0.6601483774498913
# Electrical Efficiency: 0.32847370621889604
# Vertical Cost of Transport: 1.2513544041358353
# Passive Efficiency: 0.18446019779806744
#
#
# hsa_1300g, hop_idx=39
# Stance work:
# Thermal loss: 0.6204844589626257
# Motor work: (1.5125468164934228, -0.0900195842810709)
# Joint work: (1.9540170471627811, -0.9939347465053174)
# Flight work:
# Thermal loss: 0.02422651046952428
# Motor work: (0.06626013138752186, -0.15473758716331856)
# Joint work: (0.044329063720152634, -0.38953084360333834)
# Total:
# Thermal loss: 0.64471096943215
# Motor work: 1.3340497764365553
#
#
# Hop Height: 5.166312651727329
# Joint work: 0.6148805207742778
# Hop Energy: 0.6588598524747863
# Electrical Efficiency: 0.3329658999201225
# Vertical Cost of Transport: 1.2268123915385256
# Passive Efficiency: 0.2099431928819493
#
#
# hsa_1300g, hop_idx=40
# Stance work:
# Thermal loss: 0.6323577724614384
# Motor work: (1.5244208762698657, -0.09103785577207453)
# Joint work: (1.92743352909933, -0.9699941590252367)
# Flight work:
# Thermal loss: 0.02429373238339344
# Motor work: (0.0651197406011305, -0.15587572202870784)
# Joint work: (0.042974395790396705, -0.38330032577698747)
# Total:
# Thermal loss: 0.6566515048448318
# Motor work: 1.342627039070214
#
#
# Hop Height: 5.107751606377461
# Joint work: 0.6171134400875027
# Hop Energy: 0.6513915623613177
# Electrical Efficiency: 0.3258133111786133
# Vertical Cost of Transport: 1.253544516039095
# Passive Efficiency: 0.1932936338753538
#
#
# hsa_1300g, hop_idx=41
# Stance work:
# Thermal loss: 0.6290898001686099
# Motor work: (1.5320129351095428, -0.08725222506180581)
# Joint work: (1.9219158120123636, -0.95918490218894)
# Flight work:
# Thermal loss: 0.023849667717276906
# Motor work: (0.06957050760325459, -0.1487956056047169)
# Joint work: (0.046252175768597255, -0.3953177168102826)
# Total:
# Thermal loss: 0.6529394678858869
# Motor work: 1.3655356120462747
#
#
# Hop Height: 5.1813758428127015
# Joint work: 0.6136653687817382
# Hop Energy: 0.6607808612339039
# Electrical Efficiency: 0.32736637068420577
# Vertical Cost of Transport: 1.2485788727076133
# Passive Efficiency: 0.18625673588029157
#
#
# hsa_1300g, hop_idx=42
# Stance work:
# Thermal loss: 0.6180449071205123
# Motor work: (1.5330120906634956, -0.08668536881510754)
# Joint work: (1.952294205870303, -0.9712417163089662)
# Flight work:
# Thermal loss: 0.024136652699413553
# Motor work: (0.06420348592711421, -0.15871836300846265)
# Joint work: (0.04317010111948015, -0.39243689774285295)
# Total:
# Thermal loss: 0.6421815598199259
# Motor work: 1.3518118447670395
#
#
# Hop Height: 5.243632467227018
# Joint work: 0.6317856929379639
# Hop Energy: 0.6687204485454616
# Electrical Efficiency: 0.33536743251363965
# Vertical Cost of Transport: 1.208503657734038
# Passive Efficiency: 0.1995769751451697
#
#
# hsa_1300g, hop_idx=43
# Stance work:
# Thermal loss: 0.6363921945193387
# Motor work: (1.5656337474632878, -0.09040931780365016)
# Joint work: (1.9355744349668782, -0.9606291779914704)
# Flight work:
# Thermal loss: 0.024767126031522212
# Motor work: (0.06573962469882386, -0.15803658300297774)
# Joint work: (0.04569506584073279, -0.392492316011994)
# Total:
# Thermal loss: 0.6611593205508609
# Motor work: 1.3829274713554836
#
#
# Hop Height: 5.205523233173634
# Joint work: 0.6281480068041465
# Hop Energy: 0.6638603779266335
# Electrical Efficiency: 0.32477113034300653
# Vertical Cost of Transport: 1.2608401419885578
# Passive Efficiency: 0.1766019860008311
#
#
# hsa_1300g, hop_idx=44
# Stance work:
# Thermal loss: 0.6245084077706996
# Motor work: (1.5213178207783449, -0.09162933918322566)
# Joint work: (1.9281964155894018, -0.979928050499833)
# Flight work:
# Thermal loss: 0.025654100833819922
# Motor work: (0.06448371817131121, -0.1660205406430071)
# Joint work: (0.042188069916045894, -0.3834227009047896)
# Total:
# Thermal loss: 0.6501625086045195
# Motor work: 1.3281516591234233
#
#
# Hop Height: 5.131348435140311
# Joint work: 0.6070337341008252
# Hop Energy: 0.654400865933444
# Electrical Efficiency: 0.3307871300770248
# Vertical Cost of Transport: 1.231552364507114
# Passive Efficiency: 0.19518167615755333
#
#
# hsa_1300g, hop_idx=45
# Stance work:
# Thermal loss: 0.6162013979364992
# Motor work: (1.486465335194575, -0.08987446670919155)
# Joint work: (1.8907544346592642, -0.9654982474837781)
# Flight work:
# Thermal loss: 0.024002028930595644
# Motor work: (0.06891302632310918, -0.14866789923386728)
# Joint work: (0.039310421487515214, -0.37022270807521607)
# Total:
# Thermal loss: 0.6402034268670949
# Motor work: 1.3168359955746254
#
#
# Hop Height: 4.996159318187187
# Joint work: 0.5943439005877853
# Hop Energy: 0.637160197848412
# Electrical Efficiency: 0.3255735119803834
# Vertical Cost of Transport: 1.2433157062659832
# Passive Efficiency: 0.1941315564789502
#
#
# hsa_1300g, hop_idx=46
# Stance work:
# Thermal loss: 0.6331866002699132
# Motor work: (1.5282658497311101, -0.09087084759139347)
# Joint work: (1.9166908394555862, -0.9684627714989575)
# Flight work:
# Thermal loss: 0.023713639796103365
# Motor work: (0.06475549990093779, -0.1521034099816721)
# Joint work: (0.04164674333357387, -0.3811304728561963)
# Total:
# Thermal loss: 0.6569002400660167
# Motor work: 1.3500470920589824
#
#
# Hop Height: 5.079091579299982
# Joint work: 0.6087443384340061
# Hop Energy: 0.6477365491081267
# Electrical Efficiency: 0.32274715870211174
# Vertical Cost of Transport: 1.2645893559276353
# Passive Efficiency: 0.18654405469602986
#
#
# hsa_1300g, hop_idx=47
# Stance work:
# Thermal loss: 0.6225662511557171
# Motor work: (1.501260592329349, -0.08932369835396406)
# Joint work: (1.8987781209589165, -0.9428677770533029)
# Flight work:
# Thermal loss: 0.025088023776715485
# Motor work: (0.06764281318836317, -0.15565715695359275)
# Joint work: (0.03967883764544848, -0.379209273995314)
# Total:
# Thermal loss: 0.6476542749324325
# Motor work: 1.3239225502101553
#
#
# Hop Height: 5.038212909319751
# Joint work: 0.6163799075557479
# Hop Energy: 0.642523292325548
# Electrical Efficiency: 0.3258931045099293
# Vertical Cost of Transport: 1.2507003100384735
# Passive Efficiency: 0.19064315637563667
#
#
# hsa_1300g, hop_idx=48
# Stance work:
# Thermal loss: 0.5728990894940826
# Motor work: (1.4567024697340276, -0.08340016938693541)
# Joint work: (1.8832692159049862, -0.8914977883449537)
# Flight work:
# Thermal loss: 0.02330586747842684
# Motor work: (0.06463909835089018, -0.14717304548662502)
# Joint work: (0.04073632187765458, -0.370038931853065)
# Total:
# Thermal loss: 0.5962049569725095
# Motor work: 1.2907683532113574
#
#
# Hop Height: 4.920256868099419
# Joint work: 0.6624688175846221
# Hop Energy: 0.627480358388719
# Electrical Efficiency: 0.3325327152229711
# Vertical Cost of Transport: 1.2313816941577633
# Passive Efficiency: 0.20928420515971136
#
#
# hsa_1300g, hop_idx=49
# Stance work:
# Thermal loss: 0.6265981098368639
# Motor work: (1.5219216018406767, -0.08685606872705498)
# Joint work: (1.9069960832435746, -0.9608200314183031)
# Flight work:
# Thermal loss: 0.025000003957565516
# Motor work: (0.0671962212345702, -0.1558905584518886)
# Joint work: (0.04171880311285113, -0.3816631197470151)
# Total:
# Thermal loss: 0.6515981137944294
# Motor work: 1.3463711958963034
#
#
# Hop Height: 5.061283140783089
# Joint work: 0.6062317351911075
# Hop Energy: 0.6454654389440674
# Electrical Efficiency: 0.32306073762663523
# Vertical Cost of Transport: 1.2703278665598319
# Passive Efficiency: 0.18453036193176975
#
#
# hsa_1300g, hop_idx=50
# Stance work:
# Thermal loss: 0.62012744170215
# Motor work: (1.508566709551072, -0.08905106532849656)
# Joint work: (1.8726322333564331, -0.9599698006002348)
# Flight work:
# Thermal loss: 0.02427339421933944
# Motor work: (0.0700221180674963, -0.1485858610443925)
# Joint work: (0.04121564052366759, -0.3637086672798607)
# Total:
# Thermal loss: 0.6444008359214894
# Motor work: 1.3409519012456792
#
#
# Hop Height: 4.8828156563991465
# Joint work: 0.5901694060000053
# Hop Energy: 0.6227054806605832
# Electrical Efficiency: 0.31364979582877556
# Vertical Cost of Transport: 1.2952813306183495
# Passive Efficiency: 0.17517538924440967
#
#
# hsa_1300g, hop_idx=51
# Stance work:
# Thermal loss: 0.6332164448122166
# Motor work: (1.5549265391148903, -0.08808422834475389)
# Joint work: (1.9312992810360692, -0.9637373701827094)
# Flight work:
# Thermal loss: 0.023990028197310064
# Motor work: (0.06708728557083624, -0.15148097261104465)
# Joint work: (0.04306292387129219, -0.39193842002858337)
# Total:
# Thermal loss: 0.6572064730095267
# Motor work: 1.382448623729928
#
#
# Hop Height: 5.210387986939299
# Joint work: 0.6186864146960687
# Hop Energy: 0.6644807799743688
# Electrical Efficiency: 0.3257809523956243
# Vertical Cost of Transport: 1.2563216294038937
# Passive Efficiency: 0.17846187459720309
#
#
# hsa_1300g, hop_idx=52
# Stance work:
# Thermal loss: 0.6235247267701036
# Motor work: (1.546917249524458, -0.09018907373541893)
# Joint work: (1.9421321628093748, -0.9784554464857503)
# Flight work:
# Thermal loss: 0.024989302312436196
# Motor work: (0.06454327882311481, -0.16273757346945814)
# Joint work: (0.04242328984578508, -0.39232986908516715)
# Total:
# Thermal loss: 0.6485140290825399
# Motor work: 1.358533881142696
#
#
# Hop Height: 5.181579714350999
# Joint work: 0.6137701370842423
# Hop Energy: 0.660806860971183
# Electrical Efficiency: 0.3292431922549501
# Vertical Cost of Transport: 1.2430609443000131
# Passive Efficiency: 0.18799924376434984
#
#
# hsa_1300g, hop_idx=53
# Stance work:
# Thermal loss: 0.6300103955156315
# Motor work: (1.5508242025863503, -0.09298129773224849)
# Joint work: (1.954509983975751, -0.9754628626320292)
# Flight work:
# Thermal loss: 0.024668343440368588
# Motor work: (0.0658792799940254, -0.15816622704423072)
# Joint work: (0.04333121371275801, -0.3929123188981428)
# Total:
# Thermal loss: 0.6546787389560002
# Motor work: 1.3655559578038965
#
#
# Hop Height: 5.218801537420338
# Joint work: 0.6294660161583367
# Hop Energy: 0.6655537600672157
# Electrical Efficiency: 0.3294437825143027
# Vertical Cost of Transport: 1.2415809386962944
# Passive Efficiency: 0.19077478007216364
#
#
# hsa_1300g, hop_idx=54
# Stance work:
# Thermal loss: 0.6294996629400631
# Motor work: (1.5518185676957699, -0.09388597916022906)
# Joint work: (1.9559296675560207, -0.97635791747283)
# Flight work:
# Thermal loss: 0.02556642727889142
# Motor work: (0.06756729931532016, -0.16234895491613377)
# Joint work: (0.04575095054309121, -0.3974494188358455)
# Total:
# Thermal loss: 0.6550660902189546
# Motor work: 1.3631509329347273
#
#
# Hop Height: 5.23819314248812
# Joint work: 0.6278732817904364
# Hop Energy: 0.66802677146151
# Electrical Efficiency: 0.3309984822235054
# Vertical Cost of Transport: 1.2438125641248623
# Passive Efficiency: 0.19098688753406945
#
#
# hsa_1300g, hop_idx=55
# Stance work:
# Thermal loss: 0.626483364025755
# Motor work: (1.5419235113081688, -0.0906767020798658)
# Joint work: (1.9382716031980531, -0.9690146693704144)
# Flight work:
# Thermal loss: 0.025267944031732797
# Motor work: (0.06739713677159917, -0.1587175779328075)
# Joint work: (0.04300887115343815, -0.38883516948050334)
# Total:
# Thermal loss: 0.6517513080574878
# Motor work: 1.3599263680670945
#
#
# Hop Height: 5.166623336809951
# Joint work: 0.6234306355005736
# Hop Energy: 0.6588994741433731
# Electrical Efficiency: 0.3275372998186852
# Vertical Cost of Transport: 1.2501906560541503
# Passive Efficiency: 0.18773708775052278
#
#
# hsa_1300g, hop_idx=56
# Stance work:
# Thermal loss: 0.6190996396048282
# Motor work: (1.5276103572719133, -0.08905385861063447)
# Joint work: (1.9430380988271418, -0.989320823513943)
# Flight work:
# Thermal loss: 0.024270016178477787
# Motor work: (0.06874591918839644, -0.15217206303810177)
# Joint work: (0.039836314219408496, -0.38296595029114)
# Total:
# Thermal loss: 0.643369655783306
# Motor work: 1.3551303548115734
#
#
# Hop Height: 5.160660687415007
# Joint work: 0.6105876392414673
# Hop Energy: 0.6581390574660358
# Electrical Efficiency: 0.32931651437426424
# Vertical Cost of Transport: 1.2313076609913027
# Passive Efficiency: 0.19492819819707197
#
#
# hsa_1300g, hop_idx=57
# Stance work:
# Thermal loss: 0.634255563552996
# Motor work: (1.5424606245261958, -0.09416449705927535)
# Joint work: (1.9246497384713392, -0.9740844839142846)
# Flight work:
# Thermal loss: 0.024640089166575792
# Motor work: (0.06943790025584562, -0.15261522282457055)
# Joint work: (0.04026357675126813, -0.3847265823449823)
# Total:
# Thermal loss: 0.6588956527195717
# Motor work: 1.3651188048981955
#
#
# Hop Height: 5.129505054204726
# Joint work: 0.6061022489633405
# Hop Energy: 0.6541657795627288
# Electrical Efficiency: 0.3232021278803866
# Vertical Cost of Transport: 1.2658059015729362
# Passive Efficiency: 0.17965921840199472
#
#
# hsa_1300g, hop_idx=58
# Stance work:
# Thermal loss: 0.6261717961365809
# Motor work: (1.5127837376592554, -0.09575762325803078)
# Joint work: (2.0412567653029146, -0.9916607703280145)
# Flight work:
# Thermal loss: 0.02555345561012714
# Motor work: (0.06971856133782649, -0.15806903381510568)
# Joint work: (0.04088392816635414, -0.3834685597957105)
# Total:
# Thermal loss: 0.651725251746708
# Motor work: 1.3286756419239454
#
#
# Hop Height: 5.123425322439185
# Joint work: 0.7070113633455435
# Hop Energy: 0.6533904313706693
# Electrical Efficiency: 0.32992836625094457
# Vertical Cost of Transport: 1.247549241320553
# Passive Efficiency: 0.23996380073610102
#
#
# hsa_1300g, hop_idx=59
# Stance work:
# Thermal loss: 0.6138812042303102
# Motor work: (1.4783367499578863, -0.09119595573156089)
# Joint work: (1.8534602655337025, -0.953344227681409)
# Flight work:
# Thermal loss: 0.024915526988616914
# Motor work: (0.06383582939820191, -0.16146909772857204)
# Joint work: (0.037476204215872076, -0.3698885361747707)
# Total:
# Thermal loss: 0.6387967312189271
# Motor work: 1.2895075258959554
#
#
# Hop Height: 5.025471512958222
# Joint work: 0.5677037058933949
# Hop Energy: 0.6408983820475621
# Electrical Efficiency: 0.3323637230394702
# Vertical Cost of Transport: 1.228827682144916
# Passive Efficiency: 0.18443977149569424
#
#
# hsa_1300g, hop_idx=60
# Stance work:
# Thermal loss: 0.6162670929521845
# Motor work: (1.4647142374880846, -0.09068281761868369)
# Joint work: (1.8113411775250488, -0.9271210830737675)
# Flight work:
# Thermal loss: 0.024534481165508937
# Motor work: (0.06542559873987533, -0.15430708250715217)
# Joint work: (0.03762001020761389, -0.3660531845491248)
# Total:
# Thermal loss: 0.6408015741176935
# Motor work: 1.2851499361021241
#
#
# Hop Height: 4.962336849829324
# Joint work: 0.5557869201097703
# Hop Energy: 0.6328468184587338
# Electrical Efficiency: 0.3285891753248264
# Vertical Cost of Transport: 1.2372794983651403
# Passive Efficiency: 0.17243269010728435
#
#
# hsa_1300g, hop_idx=61
# Stance work:
# Thermal loss: 0.6121113195889261
# Motor work: (1.4641312714546366, -0.0830101314532008)
# Joint work: (1.849965747519281, -0.9562498790112239)
# Flight work:
# Thermal loss: 0.023557610712821433
# Motor work: (0.06627739902140463, -0.1502610456590343)
# Joint work: (0.0388559974052525, -0.367242544408997)
# Total:
# Thermal loss: 0.6356689303017475
# Motor work: 1.2971374933638062
#
#
# Hop Height: 4.993087302617995
# Joint work: 0.5653293215043125
# Hop Energy: 0.6367684237028729
# Electrical Efficiency: 0.32945276666415774
# Vertical Cost of Transport: 1.2365491926546013
# Passive Efficiency: 0.18975484341578897
#
#
# hsa_1300g, hop_idx=62
# Stance work:
# Thermal loss: 0.6102078813060897
# Motor work: (1.45135297271343, -0.09059208293727736)
# Joint work: (1.828827817431069, -0.944459572205964)
# Flight work:
# Thermal loss: 0.02420718485982618
# Motor work: (0.06715688466542036, -0.15046560154731078)
# Joint work: (0.03586481595071568, -0.3629754685314316)
# Total:
# Thermal loss: 0.6344150661659159
# Motor work: 1.2774521728942623
#
#
# Hop Height: 4.9280864973458405
# Joint work: 0.5572575926443892
# Hop Energy: 0.6284788710065151
# Electrical Efficiency: 0.3287251636339865
# Vertical Cost of Transport: 1.241638409174404
# Passive Efficiency: 0.18565138822643457
#
#
# hsa_1300g, hop_idx=63
# Stance work:
# Thermal loss: 0.6316969567529485
# Motor work: (1.499889437560372, -0.08638248099740607)
# Joint work: (1.8487186069512027, -0.9410096049088712)
# Flight work:
# Thermal loss: 0.025008828134702798
# Motor work: (0.06527403350047818, -0.15994062499207182)
# Joint work: (0.03993322767970068, -0.370895509140523)
# Total:
# Thermal loss: 0.6567057848876513
# Motor work: 1.3188403650713723
#
#
# Hop Height: 4.9512317164156805
# Joint work: 0.5767467205815091
# Hop Energy: 0.6314305807944918
# Electrical Efficiency: 0.3196233005275978
# Vertical Cost of Transport: 1.2752288651123447
# Passive Efficiency: 0.17128004094691818
#
#
# hsa_1300g, hop_idx=64
# Stance work:
# Thermal loss: 0.6132967493114291
# Motor work: (1.4708254042888504, -0.08844152382343107)
# Joint work: (1.8478216490537807, -0.951063395034602)
# Flight work:
# Thermal loss: 0.025285644287147906
# Motor work: (0.06512553952881603, -0.16117331577781857)
# Joint work: (0.0369127002356515, -0.3649568017799356)
# Total:
# Thermal loss: 0.6385823935985769
# Motor work: 1.2863361042164168
#
#
# Hop Height: 4.961986256236084
# Joint work: 0.5687141524748947
# Hop Energy: 0.6328021072577878
# Electrical Efficiency: 0.3287422859596871
# Vertical Cost of Transport: 1.2441749542913403
# Passive Efficiency: 0.1850570641975413
#
#
# hsa_1300g, hop_idx=65
# Stance work:
# Thermal loss: 0.6154716020395045
# Motor work: (1.4880411332916446, -0.09150403807183222)
# Joint work: (1.8683253141404246, -0.9523968435653023)
# Flight work:
# Thermal loss: 0.02454240276552176
# Motor work: (0.06542561052357287, -0.15603339826428708)
# Joint work: (0.038150740216073245, -0.37245628404689013)
# Total:
# Thermal loss: 0.6400140048050262
# Motor work: 1.305929307479098
#
#
# Hop Height: 5.059351102946579
# Joint work: 0.5816229267443054
# Hop Energy: 0.6452190461587772
# Electrical Efficiency: 0.33157134747231
# Vertical Cost of Transport: 1.237971258427412
# Passive Efficiency: 0.1851632543375602
#
#
# hsa_1300g, hop_idx=66
# Stance work:
# Thermal loss: 0.6066754810103706
# Motor work: (1.4745700505910422, -0.09024341201365989)
# Joint work: (1.8707608546105652, -0.957475580422142)
# Flight work:
# Thermal loss: 0.02328275744226793
# Motor work: (0.06634926284006841, -0.14845972028399304)
# Joint work: (0.03603790005716382, -0.3725312717606338)
# Total:
# Thermal loss: 0.6299582384526385
# Motor work: 1.3022161811334576
#
#
# Hop Height: 5.049341551331059
# Joint work: 0.5767919024849533
# Hop Energy: 0.64394252804125
# Electrical Efficiency: 0.33327349824825503
# Vertical Cost of Transport: 1.222929390717461
# Passive Efficiency: 0.1918815188760573
#
#
# hsa_1300g, hop_idx=67
# Stance work:
# Thermal loss: 0.6141037307284254
# Motor work: (1.4999493838389966, -0.08436949487940246)
# Joint work: (1.875665455132778, -0.9475866501622855)
# Flight work:
# Thermal loss: 0.02576864153432773
# Motor work: (0.06624670598431426, -0.16022873202851579)
# Joint work: (0.04194681836726164, -0.3784537910685061)
# Total:
# Thermal loss: 0.6398723722627531
# Motor work: 1.3215978629153924
#
#
# Hop Height: 5.102007639286884
# Joint work: 0.591571832269248
# Hop Energy: 0.6506590342382564
# Electrical Efficiency: 0.3317200651679336
# Vertical Cost of Transport: 1.2405574966150432
# Passive Efficiency: 0.18325716232266365
#
#
# hsa_1300g, hop_idx=68
# Stance work:
# Thermal loss: 0.6296073886784711
# Motor work: (1.521902590517352, -0.09249647932764707)
# Joint work: (1.8880921274243543, -0.9567667483541362)
# Flight work:
# Thermal loss: 0.025732560297043985
# Motor work: (0.06509997150026738, -0.16530398349785205)
# Joint work: (0.044883387440456085, -0.38611062217189546)
# Total:
# Thermal loss: 0.6553399489755151
# Motor work: 1.3292020991921203
#
#
# Hop Height: 5.096331102088268
# Joint work: 0.5900981443387787
# Hop Energy: 0.6499351054493168
# Electrical Efficiency: 0.32749878293050727
# Vertical Cost of Transport: 1.259763464500006
# Passive Efficiency: 0.17898465354921367
#
#
# hsa_1300g, hop_idx=69
# Stance work:
# Thermal loss: 0.6304435199443587
# Motor work: (1.5360739394253584, -0.09123682751293136)
# Joint work: (1.9123047853364732, -0.9716385440895647)
# Flight work:
# Thermal loss: 0.025684871249529992
# Motor work: (0.06561482047348498, -0.16471788999522735)
# Joint work: (0.0448228287583487, -0.3902158430247311)
# Total:
# Thermal loss: 0.6561283911938887
# Motor work: 1.3457340423906847
#
#
# Hop Height: 5.1522938951915815
# Joint work: 0.5952732269805261
# Hop Energy: 0.6570720404537824
# Electrical Efficiency: 0.32823036659777693
# Vertical Cost of Transport: 1.2593018883426557
# Passive Efficiency: 0.1816125078590597
#
#
# hsa_1300g, hop_idx=70
# Stance work:
# Thermal loss: 0.6227571638832013
# Motor work: (1.5368751374016458, -0.0871819580483235)
# Joint work: (1.9392790869598846, -0.9881664055076539)
# Flight work:
# Thermal loss: 0.025105174343054915
# Motor work: (0.06723991279844138, -0.15930790326944916)
# Joint work: (0.04190282443377139, -0.3886665739485585)
# Total:
# Thermal loss: 0.6478623382262563
# Motor work: 1.3576251888823145
#
#
# Hop Height: 5.159092400153957
# Joint work: 0.6043489319374435
# Hop Energy: 0.6579390537916343
# Electrical Efficiency: 0.3280693820819837
# Vertical Cost of Transport: 1.2435781661988627
# Passive Efficiency: 0.19032419942110335
#
#
# hsa_1300g, hop_idx=71
# Stance work:
# Thermal loss: 0.6112209892840613
# Motor work: (1.4956483376870529, -0.08590002862077392)
# Joint work: (1.877414692617705, -0.9563295670671894)
# Flight work:
# Thermal loss: 0.026152387694393132
# Motor work: (0.06520002806846915, -0.16523861900371373)
# Joint work: (0.0395136336951263, -0.37475108753273695)
# Total:
# Thermal loss: 0.6373733769784544
# Motor work: 1.3097097181310344
#
#
# Hop Height: 5.041509118616563
# Joint work: 0.5858476717129051
# Hop Energy: 0.6429436578971705
# Electrical Efficiency: 0.33020863850754983
# Vertical Cost of Transport: 1.2397094953940988
# Passive Efficiency: 0.18575549000427216
#
#
# hsa_1300g, hop_idx=72
# Stance work:
# Thermal loss: 0.6158979290309156
# Motor work: (1.4807087890871753, -0.08914073375970624)
# Joint work: (1.8593299898808635, -0.9618644015395218)
# Flight work:
# Thermal loss: 0.023999052127649738
# Motor work: (0.06583916119391689, -0.15605382113750546)
# Joint work: (0.035356376604254496, -0.365858133347449)
# Total:
# Thermal loss: 0.6398969811585653
# Motor work: 1.3013533953838805
#
#
# Hop Height: 5.00025513815152
# Joint work: 0.5669638315981471
# Hop Energy: 0.6376825377684633
# Electrical Efficiency: 0.3284906189711795
# Vertical Cost of Transport: 1.2413570214455996
# Passive Efficiency: 0.183744614603348
#
#
# hsa_1300g, hop_idx=73
# Stance work:
# Thermal loss: 0.613941942387604
# Motor work: (1.4855353141100596, -0.09405363133832731)
# Joint work: (1.8709425488414946, -0.9569875750395184)
# Flight work:
# Thermal loss: 0.024210965090443102
# Motor work: (0.06679645688750982, -0.1569137254801182)
# Joint work: (0.03797139305255406, -0.3712093999031604)
# Total:
# Thermal loss: 0.6381529074780471
# Motor work: 1.3013644141791239
#
#
# Hop Height: 5.053662656979802
# Joint work: 0.5807169669513699
# Hop Energy: 0.6444935986446342
# Electrical Efficiency: 0.3322958714769111
# Vertical Cost of Transport: 1.2315130637230156
# Passive Efficiency: 0.18679845281169338
#
#
# hsa_1300g, hop_idx=74
# Stance work:
# Thermal loss: 0.6054587702088222
# Motor work: (1.467597393227288, -0.09107927330817948)
# Joint work: (1.863074598230369, -0.9619558961204985)
# Flight work:
# Thermal loss: 0.024817134293777424
# Motor work: (0.0653829810797819, -0.1604774395197212)
# Joint work: (0.03812419914141702, -0.3718712748985803)
# Total:
# Thermal loss: 0.6302759045025996
# Motor work: 1.2814236614791694
#
#
# Hop Height: 5.043038643452949
# Joint work: 0.5673716263527071
# Hop Energy: 0.6431387181995546
# Electrical Efficiency: 0.3364224848109255
# Vertical Cost of Transport: 1.223910114343181
# Passive Efficiency: 0.19367697032721687
#
#
# hsa_1300g, hop_idx=75
# Stance work:
# Thermal loss: 0.6126209216682487
# Motor work: (1.480606372526968, -0.09443185363156127)
# Joint work: (1.8565403459424918, -0.9510313488552868)
# Flight work:
# Thermal loss: 0.025292848159976167
# Motor work: (0.06623680283380247, -0.16021098764425773)
# Joint work: (0.03778578338017255, -0.37257760202494866)
# Total:
# Thermal loss: 0.6379137698282248
# Motor work: 1.2922003340849515
#
#
# Hop Height: 5.02787670647883
# Joint work: 0.5707171784424288
# Hop Energy: 0.6412051163772452
# Electrical Efficiency: 0.3322109895354088
# Vertical Cost of Transport: 1.2396435645936255
# Passive Efficiency: 0.18343354324428807
#
#
# hsa_1300g, hop_idx=76
# Stance work:
# Thermal loss: 0.6162488059364176
# Motor work: (1.4865486753625994, -0.09240763753613454)
# ...
# Thermal loss: 2.605255225414992
# Motor work: 1.45136630432849
#
#
# Hop Height: 5.2418122694781
# Joint work: 1.111327242976372
# Hop Energy: 0.977021388908023
# Electrical Efficiency: 0.2408460788723873
# Vertical Cost of Transport: 2.5797508662946584
# Passive Efficiency: 0.050188040931476774
#
#
# no_hsa_1900g, hop_idx=42
# Stance work:
# Thermal loss: 2.4782689804596454
# Motor work: (3.2149817981654314, -1.4905988365917813)
# Joint work: (3.443910171274966, -2.0699267755666453)
# Flight work:
# Thermal loss: 0.12332821925153466
# Motor work: (0.09204376145514612, -0.34735281679699953)
# Joint work: (0.033989201840952374, -0.3849450821812954)
# Total:
# Thermal loss: 2.60159719971118
# Motor work: 1.4690739062317966
#
#
# Hop Height: 5.266528779303185
# Joint work: 1.0230275153679775
# Hop Energy: 0.9816282991743206
# Electrical Efficiency: 0.24114655142273528
# Vertical Cost of Transport: 2.576423408425256
# Passive Efficiency: 0.04913132761004868
#
#
# no_hsa_1900g, hop_idx=43
# Stance work:
# Thermal loss: 2.4933975123192336
# Motor work: (3.242675816814735, -1.496591386214038)
# Joint work: (3.463891083749834, -2.102497889505216)
# Flight work:
# Thermal loss: 0.12513958183000595
# Motor work: (0.0946980673326481, -0.35165240863339375)
# Joint work: (0.03529706830085437, -0.3822710077141616)
# Total:
# Thermal loss: 2.6185370941492394
# Motor work: 1.4891300892999513
#
#
# Hop Height: 5.209090591471592
# Joint work: 1.0144192548313105
# Hop Energy: 0.9709223953443902
# Electrical Efficiency: 0.2363683209916512
# Vertical Cost of Transport: 2.6224371646149938
# Passive Efficiency: 0.04624337442628634
#
#
# no_hsa_1900g, hop_idx=44
# Stance work:
# Thermal loss: 2.487164474402708
# Motor work: (3.231534270232084, -1.4917910641139)
# Joint work: (3.451382868476878, -2.0798123526969765)
# Flight work:
# Thermal loss: 0.12883935901676502
# Motor work: (0.09132168877123707, -0.3545656493553153)
# Joint work: (0.0363871935276015, -0.3869744064241271)
# Total:
# Thermal loss: 2.616003833419473
# Motor work: 1.476499245534106
#
#
# Hop Height: 5.264925495176668
# Joint work: 1.020983302883376
# Hop Energy: 0.9813294630459793
# Electrical Efficiency: 0.2397871043989288
# Vertical Cost of Transport: 2.585830617863716
# Passive Efficiency: 0.047283536491617095
#
#
# no_hsa_1900g, hop_idx=45
# Stance work:
# Thermal loss: 2.4853739887281834
# Motor work: (3.2559403994277725, -1.4980653144462206)
# Joint work: (3.4572096312470566, -2.087529620140455)
# Flight work:
# Thermal loss: 0.12558725422449862
# Motor work: (0.09333454748671405, -0.3536479614711787)
# Joint work: (0.0347499944967442, -0.3859429560674653)
# Total:
# Thermal loss: 2.610961242952682
# Motor work: 1.4975616709970874
#
#
# Hop Height: 5.2467724744719755
# Joint work: 1.0184870495358807
# Hop Energy: 0.9779459215168316
# Electrical Efficiency: 0.23802859129649429
# Vertical Cost of Transport: 2.6025782063956537
# Passive Efficiency: 0.04086091883119114
#
#
# no_hsa_1900g, hop_idx=46
# Stance work:
# Thermal loss: 2.4886916568914432
# Motor work: (3.26979451915306, -1.5200633952546574)
# Joint work: (3.5379570731752255, -2.138723198950849)
# Flight work:
# Thermal loss: 0.13082450709528864
# Motor work: (0.09271763088314278, -0.3606540733653967)
# Joint work: (0.03716710780909995, -0.3898929234344823)
# Total:
# Thermal loss: 2.6195161639867317
# Motor work: 1.4817946814161487
#
#
# Hop Height: 5.295071507806887
# Joint work: 1.0465080585989943
# Hop Energy: 0.9869483783401257
# Electrical Efficiency: 0.24064217893807946
# Vertical Cost of Transport: 2.5905940999777672
# Passive Efficiency: 0.05946983102824277
#
#
# no_hsa_1900g, hop_idx=47
# Stance work:
# Thermal loss: 2.4863184707414154
# Motor work: (3.266312589120294, -1.519090484536318)
# Joint work: (3.5380549431480297, -2.137546541089449)
# Flight work:
# Thermal loss: 0.1293184661501428
# Motor work: (0.09388141914079452, -0.35620531122665444)
# Joint work: (0.03559661779262997, -0.394047736386821)
# Total:
# Thermal loss: 2.6156369368915584
# Motor work: 1.4848982124981163
#
#
# Hop Height: 5.357916680714593
# Joint work: 1.0420572834643895
# Hop Energy: 0.9986620901183928
# Electrical Efficiency: 0.24354433110201093
# Vertical Cost of Transport: 2.5614892759021193
# Passive Efficiency: 0.05973093600188162
#
#
# no_hsa_1900g, hop_idx=48
# Stance work:
# Thermal loss: 2.47758210623142
# Motor work: (3.2632658480504144, -1.516239948788209)
# Joint work: (3.53416222153363, -2.123348953943239)
# Flight work:
# Thermal loss: 0.1315712204956666
# Motor work: (0.09383709653520664, -0.3627121433890935)
# Joint work: (0.0374175309780872, -0.39611107409411006)
# Total:
# Thermal loss: 2.6091533267270868
# Motor work: 1.4781508524083184
#
#
# Hop Height: 5.37406737638272
# Joint work: 1.0521197244743683
# Hop Energy: 1.0016724182839751
# Electrical Efficiency: 0.2450692129539184
# Vertical Cost of Transport: 2.553719587961295
# Passive Efficiency: 0.06005096421975875
#
#
# no_hsa_1900g, hop_idx=49
# Stance work:
# Thermal loss: 2.4923850055713
# Motor work: (3.2766747368373306, -1.5262540611358102)
# Joint work: (3.536301161200395, -2.1355282367599058)
# Flight work:
# Thermal loss: 0.12456148452296079
# Motor work: (0.09097299835282167, -0.3535004755302781)
# Joint work: (0.03695099644154757, -0.3955983039749159)
# Total:
# Thermal loss: 2.6169464900942607
# Motor work: 1.487893198524064
#
#
# Hop Height: 5.384225958589175
# Joint work: 1.042125616907121
# Hop Energy: 1.0035658764214364
# Electrical Efficiency: 0.24448357367135892
# Vertical Cost of Transport: 2.5505872792894784
# Passive Efficiency: 0.05753985819670582
#
#
# no_hsa_1900g, hop_idx=50
# Stance work:
# Thermal loss: 2.490373696940996
# Motor work: (3.286991129279347, -1.5322390296371533)
# Joint work: (3.5263716836129477, -2.127188390441508)
# Flight work:
# Thermal loss: 0.13211666684504564
# Motor work: (0.09588044505148413, -0.3627294051046554)
# Joint work: (0.03680478591281378, -0.39547618526040024)
# Total:
# Thermal loss: 2.6224903637860417
# Motor work: 1.4879031395890223
#
#
# Hop Height: 5.389782902384508
# Joint work: 1.0405118938238536
# Hop Energy: 1.0046016351754485
# Electrical Efficiency: 0.2444052216291616
# Vertical Cost of Transport: 2.551404760128614
# Passive Efficiency: 0.05060229172958364
#
#
# no_hsa_1900g, hop_idx=51
# Stance work:
# Thermal loss: 2.4566048559902596
# Motor work: (3.263389484167316, -1.5116812114498683)
# Joint work: (3.515398137353828, -2.1313765588407065)
# Flight work:
# Thermal loss: 0.13022722395432784
# Motor work: (0.09252746853076513, -0.35575300013556654)
# Joint work: (0.034520126368875505, -0.3926442845520049)
# Total:
# Thermal loss: 2.586832079944587
# Motor work: 1.4884827411126467
#
#
# Hop Height: 5.358762024890788
# Joint work: 1.0258974203299922
# Hop Energy: 0.998819653819394
# Electrical Efficiency: 0.24509018264269372
# Vertical Cost of Transport: 2.5463334559951942
# Passive Efficiency: 0.054649514893669204
#
#
# no_hsa_1900g, hop_idx=52
# Stance work:
# Thermal loss: 2.4750770798092607
# Motor work: (3.277684010026495, -1.5187133847409513)
# Joint work: (3.568637994281421, -2.1490152535551155)
# Flight work:
# Thermal loss: 0.12916726249072336
# Motor work: (0.09257860899317667, -0.36045801236782016)
# Joint work: (0.03560322619443924, -0.39535201858731067)
# Total:
# Thermal loss: 2.604244342299984
# Motor work: 1.4910912219109003
#
#
# Hop Height: 5.327894001723369
# Joint work: 1.059873948333434
# Hop Energy: 0.9930661629812187
# Electrical Efficiency: 0.24248712893263707
# Vertical Cost of Transport: 2.577922798355797
# Passive Efficiency: 0.06491757547384602
#
#
# no_hsa_1900g, hop_idx=53
# Stance work:
# Thermal loss: 2.4920718407274673
# Motor work: (3.2841681823110886, -1.52380780896126)
# Joint work: (3.5675832968907106, -2.147940436471497)
# Flight work:
# Thermal loss: 0.13255359361036595
# Motor work: (0.09252536514765702, -0.36661615971307804)
# Joint work: (0.03758521130157824, -0.3933859996595143)
# Total:
# Thermal loss: 2.6246254343378332
# Motor work: 1.486269578784408
#
#
# Hop Height: 5.331387619942445
# Joint work: 1.063842072061278
# Hop Energy: 0.9937173384810724
# Electrical Efficiency: 0.24172773454662858
# Vertical Cost of Transport: 2.5926943283538377
# Passive Efficiency: 0.06337428062359995
#
#
# no_hsa_1900g, hop_idx=54
# Stance work:
# Thermal loss: 2.4907228327830824
# Motor work: (3.2961205451388453, -1.5280627216415255)
# Joint work: (3.552879546002162, -2.1406926238672996)
# Flight work:
# Thermal loss: 0.12990072851390752
# Motor work: (0.09175190955777848, -0.3651591048878584)
# Joint work: (0.03687024876454292, -0.3967724641573178)
# Total:
# Thermal loss: 2.62062356129699
# Motor work: 1.4946506281672398
#
#
# Hop Height: 5.34558977709863
# Joint work: 1.0522847067420877
# Hop Energy: 0.9963644785534138
# Electrical Efficiency: 0.2421137529801219
# Vertical Cost of Transport: 2.5786907231485765
# Passive Efficiency: 0.05623716181121796
#
#
# no_hsa_1900g, hop_idx=55
# Stance work:
# Thermal loss: 2.489677134835821
# Motor work: (3.2726376391198158, -1.5145749618062687)
# Joint work: (3.564177475106669, -2.144146317505973)
# Flight work:
# Thermal loss: 0.12613183729006852
# Motor work: (0.09257017568435082, -0.36457368767213655)
# Joint work: (0.03531373116170246, -0.3908561805247679)
# Total:
# Thermal loss: 2.6158089721258895
# Motor work: 1.4860591653257613
#
#
# Hop Height: 5.389541100049885
# Joint work: 1.0644887082376306
# Hop Energy: 1.0045565656382982
# Electrical Efficiency: 0.24490220845138982
# Vertical Cost of Transport: 2.539197850914475
# Passive Efficiency: 0.06508791883036413
#
#
# no_hsa_1900g, hop_idx=56
# Stance work:
# Thermal loss: 2.4752930920170395
# Motor work: (3.282717732226764, -1.5089419788332807)
# Joint work: (3.587794326619668, -2.1460727883130306)
# Flight work:
# Thermal loss: 0.1326690990419177
# Motor work: (0.0923851251968527, -0.3653448088788631)
# Joint work: (0.03549410724828855, -0.39681033865336984)
# Total:
# Thermal loss: 2.607962191058957
# Motor work: 1.5008160697114727
#
#
# Hop Height: 5.333033103276246
# Joint work: 1.080405306901556
# Hop Energy: 0.9940240401196594
# Electrical Efficiency: 0.24192691282718956
# Vertical Cost of Transport: 2.5685529840203762
# Passive Efficiency: 0.06849732804169695
#
#
# no_hsa_1900g, hop_idx=57
# Stance work:
# Thermal loss: 2.4839001701509145
# Motor work: (3.3010848037452423, -1.5016961082436524)
# Joint work: (3.6761621136382225, -2.1881122221631104)
# Flight work:
# Thermal loss: 0.13645894653284085
# Motor work: (0.09584603431209311, -0.37090985958512285)
# Joint work: (0.03753516792666867, -0.3982962934126177)
# Total:
# Thermal loss: 2.620359116683755
# Motor work: 1.5243248702285601
#
#
# Hop Height: 5.348094766334336
# Joint work: 1.1272887659891633
# Hop Energy: 0.9968313834970569
# Electrical Efficiency: 0.24050841672000936
# Vertical Cost of Transport: 2.586606714088345
# Passive Efficiency: 0.0852967863266646
#
#
# no_hsa_1900g, hop_idx=58
# Stance work:
# Thermal loss: 2.4963154532704026
# Motor work: (3.3019330957976547, -1.5245551729323228)
# Joint work: (3.612599170936678, -2.1706921984060408)
# Flight work:
# Thermal loss: 0.13379157919489315
# Motor work: (0.09345747541019979, -0.3687258036302824)
# Joint work: (0.036886524775238176, -0.3978141537928176)
# Total:
# Thermal loss: 2.630107032465296
# Motor work: 1.5021095946452494
#
#
# Hop Height: 5.3738303167945745
# Joint work: 1.0809793435130581
# Hop Energy: 1.001628232747341
# Electrical Efficiency: 0.2423948991870085
# Vertical Cost of Transport: 2.5762392615434306
# Passive Efficiency: 0.06962491312203778
#
#
# no_hsa_1900g, hop_idx=59
# Stance work:
# Thermal loss: 2.4396143370144503
# Motor work: (3.23836968248065, -1.5141135387665416)
# Joint work: (3.5760943795331475, -2.155470567130254)
# Flight work:
# Thermal loss: 0.13237011474535576
# Motor work: (0.09155365697296627, -0.36831949724040847)
# Joint work: (0.035113828525016384, -0.38998170390606224)
# Total:
# Thermal loss: 2.571984451759806
# Motor work: 1.4474903034466662
#
#
# Hop Height: 5.339484887152438
# Joint work: 1.065755937021848
# Hop Energy: 0.995226588116343
# Electrical Efficiency: 0.24760115406303138
# Vertical Cost of Transport: 2.5238732676311737
# Passive Efficiency: 0.07789217691100714
#
#
# no_hsa_1900g, hop_idx=60
# Stance work:
# Thermal loss: 2.4587514179162646
# Motor work: (3.2458703984768555, -1.5016082179510688)
# Joint work: (3.5601985595545904, -2.14719872342166)
# Flight work:
# Thermal loss: 0.12355065464653757
# Motor work: (0.09506474316397541, -0.3515035057624231)
# Joint work: (0.03426421644121426, -0.39027331469719206)
# Total:
# Thermal loss: 2.5823020725628023
# Motor work: 1.487823417927339
#
#
# Hop Height: 5.370124323410448
# Joint work: 1.0569907378769527
# Hop Energy: 1.0009374726404734
# Electrical Efficiency: 0.24592300040359105
# Vertical Cost of Transport: 2.508950819951821
# Passive Efficiency: 0.07053283067724536
#
#
# no_hsa_1900g, hop_idx=61
# Stance work:
# Thermal loss: 2.4564212505790364
# Motor work: (3.253804952090487, -1.505370455868687)
# Joint work: (3.615369714663706, -2.1613555939357196)
# Flight work:
# Thermal loss: 0.13042982732666392
# Motor work: (0.09042892170189548, -0.36667535283899005)
# Joint work: (0.03584813518469948, -0.39520055511115915)
# Total:
# Thermal loss: 2.5868510779057003
# Motor work: 1.4721880650847055
#
#
# Hop Height: 5.3919870811049435
# Joint work: 1.0946617008015265
# Hop Energy: 1.0050124720471505
# Electrical Efficiency: 0.2475986154956688
# Vertical Cost of Transport: 2.5329001612355895
# Passive Efficiency: 0.08407714594974625
#
#
# no_hsa_1900g, hop_idx=62
# Stance work:
# Thermal loss: 2.460586234617914
# Motor work: (3.2598855030169602, -1.4885265465417148)
# Joint work: (3.538898319354148, -2.1181580008206367)
# Flight work:
# Thermal loss: 0.13085452250662838
# Motor work: (0.09107737011758577, -0.3628010781728953)
# Joint work: (0.037363841147657215, -0.39349184238507334)
# Total:
# Thermal loss: 2.5914407571245426
# Motor work: 1.4996352484199358
#
#
# Hop Height: 5.29264182129486
# Joint work: 1.0646123172960955
# Hop Energy: 0.9864955090711489
# Electrical Efficiency: 0.2411335080878941
# Vertical Cost of Transport: 2.5689761177567725
# Passive Efficiency: 0.06299853793035304
#
#
# no_hsa_1900g, hop_idx=63
# Stance work:
# Thermal loss: 2.4563097028672862
# Motor work: (3.2575621160377937, -1.4845485446402742)
# Joint work: (3.597790515796224, -2.13969594356398)
# Flight work:
# Thermal loss: 0.1273766036937899
# Motor work: (0.0916634054740931, -0.35865578008587257)
# Joint work: (0.03669330983008416, -0.392815715279384)
# Total:
# Thermal loss: 2.5836863065610762
# Motor work: 1.50602119678574
#
#
# Hop Height: 5.309493553629636
# Joint work: 1.1019721667829447
# Hop Energy: 0.9896365034610279
# Electrical Efficiency: 0.24198222064809227
# Vertical Cost of Transport: 2.556113597405395
# Passive Efficiency: 0.07848660712233735
#
#
# no_hsa_1900g, hop_idx=64
# Stance work:
# Thermal loss: 2.4573595276134466
# Motor work: (3.234040605288345, -1.486945047896617)
# Joint work: (3.520438071791971, -2.110262696736336)
# Flight work:
# Thermal loss: 0.12659727163331866
# Motor work: (0.091066991627453, -0.359665716990105)
# Joint work: (0.03610655174344837, -0.3899185372912119)
# Total:
# Thermal loss: 2.5839567992467654
# Motor work: 1.4784968320290761
#
#
# Hop Height: 5.369138542314569
# Joint work: 1.056363389507872
# Hop Energy: 1.0007537329020124
# Electrical Efficiency: 0.24634219211696423
# Vertical Cost of Transport: 2.5114481029294295
# Passive Efficiency: 0.06507356187465996
#
#
# no_hsa_1900g, hop_idx=65
# Stance work:
# Thermal loss: 2.4496706050932255
# Motor work: (3.2211424564324176, -1.4833691145172607)
# Joint work: (3.452883924510121, -2.097009401766952)
# Flight work:
# Thermal loss: 0.1286892888788846
# Motor work: (0.09030523578113464, -0.355214407913164)
# Joint work: (0.03490706068714014, -0.38249045369842755)
# Total:
# Thermal loss: 2.57835989397211
# Motor work: 1.4728641697831273
#
#
# Hop Height: 5.24129996086749
# Joint work: 1.0082911297318815
# Hop Energy: 0.9769258997060914
# Electrical Efficiency: 0.24114338884542982
# Vertical Cost of Transport: 2.5595056589076783
# Passive Efficiency: 0.050560166515751015
#
#
# no_hsa_1900g, hop_idx=66
# Stance work:
# Thermal loss: 2.461414628687197
# Motor work: (3.26451620171504, -1.4979394398580128)
# Joint work: (3.589872648649678, -2.151950117879629)
# Flight work:
# Thermal loss: 0.1277290261633946
# Motor work: (0.09143406532645511, -0.36500995641095785)
# Joint work: (0.03884676620865489, -0.3950151359219275)
# Total:
# Thermal loss: 2.5891436548505915
# Motor work: 1.4930008707725244
#
#
# Hop Height: 5.341251975915305
# Joint work: 1.0817541610567765
# Hop Energy: 0.9955559557908535
# Electrical Efficiency: 0.2438806243977576
# Vertical Cost of Transport: 2.561355195439445
# Passive Efficiency: 0.0751695341061488

# %%
# drop outliers in terms of hop height from each trial
summary_df_filt = pd.DataFrame(columns=summary_df.columns)
filter_by = ['Hop Height', 'Period', 'Electrical Loss', 'Positive Motor Work', 'Positive Joint Work', 'Negative Motor Work']
for cond, trials in conditions.items():
    for trial_idx, trial in enumerate(trials):
        mass = trial['experiment_config']['mass']/1000.
        hsa = True if 'no_hsa' not in cond else False
        keep = trial_frame = (summary_df['Trial Index'] == trial_idx) & (summary_df['Mass'] == mass) & (summary_df['HSA'] == hsa)
        for metric in filter_by:
            value = summary_df.loc[trial_frame, metric]
            mean = value.mean()
            std = value.std()
            keep = keep & (summary_df[metric]-mean < 3*std) & (summary_df[metric]-mean > -3*std)
        summary_df_filt = pd.concat((summary_df_filt, summary_df[keep & trial_frame]))
# Out:
# C:\Users\Joseph Sullivan\AppData\Local\Temp\ipykernel_13396\1272681734.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_df_filt = pd.concat((summary_df_filt, summary_df[keep & trial_frame]))

# %%
frame = (summary_df_filt['HSA'] == True)&(summary_df_filt['Mass']==1.9)
print((summary_df_filt.loc[frame, 'Max Leg Length'] - summary_df_filt.loc[frame, 'Min Leg Length']).mean())
print((summary_df_filt.loc[frame, 'Max Leg Length'] - summary_df_filt.loc[frame, 'Min Leg Length']).std())
# Out:
# 0.04889464254262067
# 0.0005486780605408838

# %%
# matplotlib configuration
import matplotlib.pyplot as plt
from cycler import cycler

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Define a custom color cycle of 10 colors
custom_colors = ['#6a0dad', '#e2a000', '#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']

# Update the default color cycler
# plt.rcParams['axes.prop_cycle'] = cycler(color=custom_colors)
plt.rc('axes', prop_cycle=cycler(color=custom_colors))

# Optional: check your settings
print("Font family:", plt.rcParams['font.family'])
print("Color cycle:", plt.rcParams['axes.prop_cycle'])
# Out:
# Font family: ['Times New Roman']
# Color cycle: cycler('color', ['#6a0dad', '#e2a000', '#1f77b4', '#2ca02c', '#ff7f0e', '#d62728'])

# %%
# looks like we can safely filter outliers by standard deviation / z-score on ouputs
masses = summary_df['Mass'].unique()
fig, axs = plt.subplots(nrows=1,ncols=len(masses),sharey=True,figsize=(10,4))
HSA_frame = summary_df['HSA'] == True
NO_HSA_frame = summary_df['HSA'] == False
for i, mass in enumerate(masses):
    mass_frame = summary_df_filt['Mass'] == mass
    summary_df_filt[mass_frame].boxplot(column='Hop Height', by='HSA', ax=axs[i])
    
axs[0].set_ylabel('Hop Height (m)')
axs[0].set_ylim(.04,.06)
fig.suptitle('Comparison of Hopping Height with HSA vs Without HSA')
fig.tight_layout()

# %%
from scipy.stats.mstats import linregress
import scipy.stats
# Need to look at the difference in normalized losses and make sure they are not correlating too strongly
# with the hop height - otherwise I will need to retake some data
"""
Take losses without HSA, subtract losses with HSA, and plot against difference in hop heights.
Will have the outliers filtered for this state.
Hopefully the data is not super strongly correlated
"""

hsa_loss_predictions = {
}

no_hsa_loss_predictions = {
}

keys = ['Thermal Loss', 
        'Positive Motor Work', 
        'Negative Motor Work', 
        # 'Positive Joint Work', 
        # 'Negative Joint Work', 
        'Electrical Loss']
labels = [r'$T$', r'$P_m$', r'$N_j$', r'$E$']
masses = summary_df_filt['Mass'].unique()
fig, axs = plt.subplots(nrows = len(masses), ncols = len(keys), figsize=(13,13), sharex=True)
Y_PRED = .052
HSA_frame = summary_df_filt['HSA'] == True
NO_HSA_frame = summary_df_filt['HSA'] == False
poly_fit = lambda coeffs, x: sum(coeffs[i]*x**i for i in range(coeffs.size))
poly_degree = 1
for i, mass in enumerate(masses):
    mass_frame = summary_df_filt['Mass'] == mass
    hsa_loss_predictions[mass] = {}
    no_hsa_loss_predictions[mass] = {}
    for j, key in enumerate(keys):
        frame = mass_frame & HSA_frame
        x_hsa = 100*summary_df_filt.loc[frame, 'Hop Height'].to_numpy()
        y_hsa = summary_df_filt.loc[frame, key].to_numpy()
        A_hsa = np.vstack(list(x_hsa**i for i in range(poly_degree+1)))
        hsa_coeffs, hsa_res, rank, s = np.linalg.lstsq(A_hsa.T,y_hsa,rcond=None)
        
        axs[i,j].scatter(x_hsa,y_hsa,color='C0')
        x_fit = np.linspace(min(x_hsa),max(x_hsa),100)
        y_fit = poly_fit(hsa_coeffs,x_fit)
        axs[i,j].plot(x_fit,y_fit,color='black')

        frame = mass_frame & NO_HSA_frame
        x_no_hsa = 100*summary_df_filt.loc[frame, 'Hop Height'].to_numpy()
        y_no_hsa = summary_df_filt.loc[frame,key].to_numpy()
        A_no_hsa = np.vstack(list(x_no_hsa**i for i in range(poly_degree+1)))
        no_hsa_coeffs, no_hsa_res, rank, s = np.linalg.lstsq(A_no_hsa.T,y_no_hsa,rcond=None)
        x_fit = np.linspace(min(x_no_hsa),max(x_no_hsa),100)
        y_fit = poly_fit(no_hsa_coeffs, x_fit)
        axs[i,j].scatter(x_no_hsa,y_no_hsa,color='C1')
        axs[i,j].plot(x_fit,y_fit,color='black')
        axs[0,j].set_title(labels[j])
        axs[i,0].set_ylabel(f'Mass = {mass}')
        axs[0,j].set_xlabel('Hop Height (cm)')
        axs[i,j].tick_params(labelbottom=True)

        # mean_x = (np.sum(x_hsa)+np.sum(x_no_hsa))/(len(x_hsa)+len(x_no_hsa))
        y1 = poly_fit(hsa_coeffs,x_hsa)
        y2 = poly_fit(no_hsa_coeffs, x_no_hsa)


        # estimate the losses at x=5cm
        z = Y_PRED
        alpha = .05
        t_crit = scipy.stats.t.ppf(alpha/2,len(x_hsa)-2)
        x_mean = np.average(x_hsa)
        y_mean = np.average(y_hsa)
        x_std = np.std(x_hsa)
        res = y1 - y_hsa
        y_std = np.std(res)
        r_sqr = 1-np.sum(res**2)/np.sum((y_hsa-y_mean)**2)
        print('HSA')
        print((mass, key))
        print(r_sqr)
        print()
        SEy_z = y_std*np.sqrt(1/len(x_hsa) + ((z-x_mean)**2) / np.sum((x_hsa-x_mean)**2))
        yerr = abs(t_crit)*SEy_z
        xerr = x_std/np.sqrt(x_hsa.size) + abs(z-x_mean)
        hsa_loss_predictions[mass][key] = (z,y,yerr,xerr,r_sqr)

        x_mean = np.average(x_no_hsa)
        y_mean = np.average(y_no_hsa)
        x_std = np.std(x_no_hsa)
        res = y2 - y_no_hsa
        y_std = np.std(res)
        r_sqr = 1-np.sum(res**2)/np.sum((y_no_hsa-y_mean)**2)
        print('Control')
        print((mass, key))
        print(r_sqr)
        print()
        SEy_z = y_std*np.sqrt(1/len(x_no_hsa) + ((z-x_mean)**2) / np.sum((x_no_hsa-x_mean)**2))
        yerr = abs(t_crit)*SEy_z
        xerr = x_std/np.sqrt(x_no_hsa.size) + abs(z-x_mean)
        no_hsa_loss_predictions[mass][key] = (z,y,yerr,xerr,r_sqr)

    fig.suptitle('Losses vs Hop Height Across Categories')
plt.savefig('Losses_vs_height.png')
# Out:
# HSA
# (1.3, 'Thermal Loss')
# 0.0716739736598444
#
# Control
# (1.3, 'Thermal Loss')
# 0.16904172400672346
#
# HSA
# (1.3, 'Positive Motor Work')
# 0.6972612730326762
#
# Control
# (1.3, 'Positive Motor Work')
# 0.2099389968814902
#
# HSA
# (1.3, 'Negative Motor Work')
# 0.22436319812000793
#
# Control
# (1.3, 'Negative Motor Work')
# 0.2927626606611229
#
# HSA
# (1.3, 'Electrical Loss')
# 0.49656300021418565
#
# Control
# (1.3, 'Electrical Loss')
# 0.13297947121518727
#
# HSA
# (1.5, 'Thermal Loss')
# 0.04418055373340868
#
# Control
# (1.5, 'Thermal Loss')
# 0.4866811060946187
#
# HSA
# (1.5, 'Positive Motor Work')
# 0.28854305389105905
#
# Control
# (1.5, 'Positive Motor Work')
# 0.20213003103263705
#
# HSA
# (1.5, 'Negative Motor Work')
# 0.19131125037643903
#
# Control
# (1.5, 'Negative Motor Work')
# 0.6882221432401725
#
# HSA
# (1.5, 'Electrical Loss')
# 0.09258401938439598
#
# Control
# (1.5, 'Electrical Loss')
# 0.10129114824653518
#
# HSA
# (1.7, 'Thermal Loss')
# 0.05254140227292681
#
# Control
# (1.7, 'Thermal Loss')
# 0.2827057318696109
#
# HSA
# (1.7, 'Positive Motor Work')
# 0.502075887762212
#
# Control
# (1.7, 'Positive Motor Work')
# 0.2701075129024827
#
# HSA
# (1.7, 'Negative Motor Work')
# 0.2528422535746768
#
# Control
# (1.7, 'Negative Motor Work')
# 0.6000854908472617
#
# HSA
# (1.7, 'Electrical Loss')
# 0.3189950623038069
#
# Control
# (1.7, 'Electrical Loss')
# 0.055108075846936555
#
# HSA
# (1.9, 'Thermal Loss')
# 0.046531337899966996
#
# Control
# (1.9, 'Thermal Loss')
# 0.003363102762770964
#
# HSA
# (1.9, 'Positive Motor Work')
# 0.0397712630705348
#
# Control
# (1.9, 'Positive Motor Work')
# 0.3281528282596531
#
# HSA
# (1.9, 'Negative Motor Work')
# 0.27348862171220745
#
# Control
# (1.9, 'Negative Motor Work')
# 0.4264066885070421
#
# HSA
# (1.9, 'Electrical Loss')
# 0.06622017127190472
#
# Control
# (1.9, 'Electrical Loss')
# 7.103384008111391e-05

# %%
"""
Different version of the primary results plot:

(A) percent reduction in COT across mass conditions, with confidence intervals
(B) change in Thermal loss vs Mechanical Loss... whether to normalize by mgh or just h is an open question
(C) direct comparison of VCOT
"""

from matplotlib.gridspec import GridSpec
import matplotlib.ticker as mtick

elec = summary_df_filt['Electrical Loss']
therm = summary_df_filt['Thermal Loss']
mech = summary_df_filt['Positive Motor Work'] + summary_df_filt['Negative Motor Work']
height = summary_df_filt['Hop Height']
mass = summary_df_filt['Mass']
masses = summary_df_filt['Mass'].unique()

# all calculations
norm = mass*height*9.81
COT = elec / norm

metrics = {
    'COT' : COT,
    'Thermal Loss': therm,
    'Motor Work': mech,
    'Electrical Loss': mech + therm
}

# frame slices
mass_frames = [summary_df_filt['Mass']==m for m in masses]
hsa_frames = [mass_frame & (summary_df_filt['HSA'] == True) for mass_frame in mass_frames]
without_hsa_frames = [mass_frame & (summary_df_filt['HSA'] == False) for mass_frame in mass_frames]


# Bootstrap our metrics to get confidence intervals
z = 2.575 # for 99% confidence
N_bootstrap = 1000
rng = np.random.default_rng(seed=42)
resample = lambda arr: arr[rng.choice(arr.size,arr.size,replace=True)]
hsa_conf= {}
without_hsa_conf = {}
for key, metric in metrics.items():
    X = [metric[frame].to_numpy() for frame in hsa_frames]
    samples = [
        np.stack([resample(arr) for i in range(N_bootstrap)])
        for arr in X 
    ]
    means = np.stack([np.average(sample, axis=1) for sample in samples])
    mean_of_means = np.average(means,axis=1)
    std_of_means = np.std(means,axis=1)
    hsa_conf[key] = np.stack([mean_of_means-z*std_of_means, mean_of_means+z*std_of_means])

    X = [metric[frame].to_numpy() for frame in without_hsa_frames]
    samples = [
        np.stack([resample(arr) for i in range(N_bootstrap)])
        for arr in X 
    ]
    means = np.stack([np.average(sample, axis=1) for sample in samples])
    mean_of_means = np.average(means,axis=1)
    std_of_means = np.std(means,axis=1)
    without_hsa_conf[key] = np.stack([mean_of_means-z*std_of_means, mean_of_means+z*std_of_means])

# %%
# Analyzing SPEAR hopping data
M = 4.9
g = 9.81
L1 = .32    # thigh
L2 = .327   # shank
theta_knee = np.array([0.74, 1.07, 1.4])
E_elec = np.array([15,17,19])
dx = np.array([.1,.2,.25])
F_max = 200
L_td = np.sqrt(L1**2+L2**2+L1*L2*np.cos(theta_knee))
E_mech = .5*F_max*dx
E_hop_potential = M*g*dx
print(E_elec/E_hop_potential)

dx_norm = dx / L_td
quad_fit = np.linalg.inv(np.array([[dx[0]**2, dx[0], 1],
              [dx[1]**2, dx[1], 1],
              [dx[2]**2, dx[2], 1]])) @ E_elec

cost_of_transport = E_elec/(M*9.81*dx)

SPEAR_COT_COMP = cost_of_transport[0]
# Out:
# [3.12051426 1.76829141 1.58106056]

# %%
with_hsa = summary_df_filt['HSA'] == True
frame = with_hsa & (summary_df_filt['Mass'] == 1.9)
hsa_spring_eff = 100*(1-summary_df_filt.loc[frame, 'Stance Positive Motor Work'] / summary_df_filt.loc[frame, 'Stance Positive Joint Work'])
spear_spring_eff = 64
fig, ax = plt.subplots(figsize=(5,4))
ax.bar([0], [hsa_spring_eff.mean()], width=.1, yerr=[3*hsa_spring_eff.std()], color='C1')
ax.bar([.15], [spear_spring_eff], width=.1, color='C0')
ax.hlines([hsa_spring_eff.mean()+3*hsa_spring_eff.std(),hsa_spring_eff.mean()-3*hsa_spring_eff.std()], xmin=[-.04, -.04], xmax=[.04,.04], color='black')
ax.set_ylabel('Efficiency %')
ax.set_xticks([0,.15])
ax.set_xticklabels(['HSA Hopper', 'SPEAR Hopper'])
ax.set_title('Spring Positive Work Efficiency')
ax.annotate(r'$\mu ± 3\sigma$', (-.025,hsa_spring_eff.mean() + 3.3*hsa_spring_eff.std()))
fig.tight_layout()
print(hsa_spring_eff.mean())
fig.savefig('spring_pos_work_eff', dpi=900)
# Out:
# 35.16570318008517

# %%
class SlipInterp:
    def __init__(self, L: float, omega: float, t_stance: float, knots = 2, degree=3):
        self.L = L
        self.omega = omega
        self.t_stance = t_stance
        self.knots = knots
        self.degree = degree
        self.position_coeffs = np.zeros((2, degree+1, knots+1))
        self.tk = tk = t_stance/2*(1+np.cos(np.linspace(-np.pi,0,knots+2)))
        self.tmat = np.zeros((3,degree+1))
        self.tmat[[0],:] = interp_covector(0,0,1,degree+1)
        self.tmat[[1],:] = interp_covector(.5,0,1,degree+1)
        self.tmat[[2],:] = interp_covector(1,0,1,degree+1)
        self.dt = np.diff(tk)
        self.diff = diff_tensor(0,1,degree+1)

    def set_from_array(self, arr: np.ndarray):
        self.position_coeffs = np.reshape(arr, (2,self.degree+1,self.knots+1), order='F')

    def get_array(self):
        return np.reshape(self.position_coeffs, self.position_coeffs.size, order='F')
    
    def evaluate_knots(self):
        vel_coeffs = np.einsum('ij,kjl->kil', self.diff, self.position_coeffs)/self.dt
        acc_coeffs = np.einsum('ij,kjl->kil', self.diff, vel_coeffs)/self.dt
        pos = np.einsum('ij,kjl->kil', self.tmat, self.position_coeffs)
        vel = np.einsum('ij,kjl->kil', self.tmat, vel_coeffs)
        acc = np.einsum('ij,kjl->kil', self.tmat, acc_coeffs)
        return pos, vel, acc
    
    def interpolate(self, t, ord=0):
        pos = np.zeros((2,t.size))
        for i in range(t.size):
            j = next(j for j in range(self.knots+1) if self.tk[j] <= t[i] <= self.tk[j+1])
            t_eval = interp_covector(t[i], self.tk[j], self.tk[j+1], self.degree+1, ord=ord)
            pos[:,[i]] = np.einsum('ij,kj->ki', t_eval, self.position_coeffs[:,:,j])
        return pos
    
    def fit_interp(self, pos, tvec):
        # least-squares interpolation fit to pos(t)
        self.position_coeffs = np.zeros(self.position_coeffs.shape)
        for i in range(self.knots+1):
            t_idx = np.array([j for j,t in enumerate(tvec) if self.tk[i] <= t <= self.tk[i+1]])
            N = t_idx.size
            A = np.zeros((N, self.degree+1))
            b = np.zeros((N, 2))
            for j in range(t_idx.size):
                A[j,:] = interp_covector(tvec[t_idx[j]], self.tk[i], self.tk[i+1], self.degree+1)
                b[j,:] = pos[:,t_idx[j]]
            coeffs, res, rank, sigma = np.linalg.lstsq(A,b)
            self.position_coeffs[0,:,i] = coeffs[:,0]
            self.position_coeffs[1,:,i] = coeffs[:,1]

    def make_initial_guess(self, theta_td: float):
        tvec = np.linspace(0,self.t_stance,2*(self.knots+1)*self.degree)
        x0 = -self.L*np.sin(theta_td)
        dx = -2*x0
        x = np.linspace(x0,x0+dx,tvec.size)
        y0 = self.L*np.cos(theta_td)
        dy = .01*L
        y = y0-dy*np.sin(np.pi/self.t_stance*tvec)
        pos = np.zeros((2,tvec.size))
        pos[0,:] = x
        pos[1,:] = y
        self.fit_interp(pos, tvec)

    def compute_positive_work(self):
        tvec = np.linspace(0,self.t_stance,2*(self.knots+1)*self.degree)
        pos = self.interpolate(tvec)
        vel = self.interpolate(tvec, ord=1)
        acc = self.interpolate(tvec, ord=2)
        l = np.sqrt(pos[0,:]**2 + pos[1,:]**2)
        Fx = (self.omega**2)*(self.L-l)*pos[0,:]/l
        Fy = (self.omega**2)*(self.L-l)*pos[1,:]/l
        Wx = np.trapz(np.clip(Fx*vel[0,:],0,np.inf),x=tvec)
        Wy = np.trapz(np.clip(Fy*vel[1,:],0,np.inf),x=tvec)
        return np.array([Wx,Wy])
    
    def compute_horizontal_speed(self):
        t = np.array([0,self.t_stance])
        p = self.interpolate(t)
        v = self.interpolate(t,ord=1)
        t_flight = 2*v[1,1]/9.81
        dx = p[0,1]-p[0,0]
        dx_total = dx + v[0,1]*t_flight
        xdot_avg = dx_total / (t_flight+self.t_stance)
        return dx_total, xdot_avg

    def compute_height_gain(self):
        t = np.array([0,self.t_stance])
        v = self.interpolate(t,ord=1)
        return (v[1,-1]**2)/(2*9.81)

    def dynamics(self, pos: np.ndarray):
        if len(pos.shape) < 2:
            _p = pos[:,np.newaxis]
        else:
            _p = pos
        l = np.sqrt(_p[0,:]**2+_p[1,:]**2)
        f = np.zeros_like(_p)
        f[0,:] = (self.omega**2)*(self.L-l)*_p[0,:,:]/l
        f[1,:] = (self.omega**2)*(self.L-l)*_p[1,:,:]/l-9.81
        return f

# %%
class SlipBC:
    def __init__(self, A: np.ndarray, B: np.ndarray, c: np.ndarray, initial_value = True):
        self.initial_value = initial_value
        self.A = A
        self.B = B
        self.c = c

    def eval(self, pos, vel):
        
        if self.initial_value:
            return self.A@pos[:,0,0] + self.B@vel[:,0,0] + self.c
        else:
            return self.A@pos[:,-1,-1] + self.B@vel[:,-1,-1] + self.c

class SlipBVP:
    def __init__(self, slerp: SlipInterp, bcs: list[SlipBC]):
        self.slerp = slerp
        self.bcs = bcs

    def continuity_constraints(self, pos: np.ndarray, vel: np.ndarray):
        c = np.zeros((4,self.slerp.knots))
        for i in range(c.shape[1]):
            c[0:2,i] = pos[:,-1,i] - pos[:,0,i+1]
            c[2:,i] = vel[:,-1,i] - vel[:,0,i+1]
        return c

    def dynamic_constraints(self, pos: np.ndarray, acc: np.ndarray):
        c = self.slerp.dynamics(pos[:,[1],:]) - acc[:,[1],:]
        return c
    
    def contact_constraints(self, acc: np.ndarray):
        return acc[1,:,:]+9.81 # non-negative constraint
    
    def boundary_conditions(self, pos: np.ndarray, vel: np.ndarray):
        return np.stack([bc.eval(pos,vel) for bc in self.bcs], axis=0)
    
    def equality_constraints(self, arr: np.ndarray):
        self.slerp.set_from_array(arr)
        pos, vel, acc = self.slerp.evaluate_knots()
        c1 = self.continuity_constraints(pos,vel)
        c2 = self.dynamic_constraints(pos,acc)

        all_constraints = np.hstack(
            [
                c1.flatten(order='F'),
                c2.flatten(order='F'),
            ]
        ) 
        if len(self.bcs) > 0:
            return np.hstack(
                [all_constraints, 
                 self.boundary_conditions(pos,vel).flatten()])

        return all_constraints
    
    def inequality_constraints(self, arr: np.ndarray):
        pos, vel, acc = self.slerp.evaluate_knots()
        return self.contact_constraints(acc).flatten()
    
"""
Example initial guess for stance boundary conditions,
L = neutral leg length for SLIP
t_stance = stance period
theta_td = stance touchdown angle
dx = stance horizontal distance traveled
dy = stance vertical distnace traveled
"""
def symmetric_stance_bvp(slerp: SlipInterp, theta_td: float):
    slerp.make_initial_guess(theta_td)
    p0 = slerp.interpolate(np.array([0]))

    bcs = [
        SlipBC(np.array([[1,0,]]), np.zeros((1,2)), -np.array([p0[0]])),
        SlipBC(np.array([[0,1]]), np.zeros((1,2)), -np.array([p0[1]])),
        SlipBC(np.array([[0,1]]), np.zeros((1,2)), -np.array([p0[1]]), initial_value=False),
    ]
    bvp = SlipBVP(slerp, bcs)
    arr = slerp.get_array()
    bvp.equality_constraints(arr)
    bvp.inequality_constraints(arr)

    dummy_cost = lambda arr: 0

    from scipy.optimize import minimize
    result = minimize(dummy_cost, arr, method='SLSQP',
                constraints = [
                    {'type' : 'eq', 'fun' : lambda arr: bvp.equality_constraints(arr)},
                    {'type' : 'ineq', 'fun': lambda arr: bvp.inequality_constraints(arr), 'lb' : 0, 'ub' : np.inf}
                ]
    )
    slerp.set_from_array(result.x)
    return slerp

# %%
# xdot_avg_spear = np.array([0.54, ])
""" Interpolating data from SPEAR horizontal running """
pix_coords = np.array([
    [154,60],
    [190,166],
    [242,272],
    [318,336],
    [413,396],
    [531,413],
    [681,454],
    [777,467]
])

pix_origin = np.array([[163,451]])

pix_scale = np.array([[.4/566, 1./112]])

xdot_spear = (pix_coords[:,0]-pix_origin[0,0])*pix_scale[0,0] + 0.1
h_cot_spear = (pix_origin[0,1]-pix_coords[:,1])*pix_scale[0,1] + 1



from scipy.optimize import root_scalar
h_eq = np.zeros_like(xdot_spear)
v_cot_eq = np.zeros_like(h_cot_spear)
t_stance = 0.36
# omega = 1.4*np.pi/t_stance
K = 1000
M = 4.91
omega = np.sqrt(K/M)
L = .5
slerp = SlipInterp(L,omega,t_stance,knots=20,degree=2)
for i in range(xdot_spear.size):
    f = lambda theta_td: symmetric_stance_bvp(slerp,theta_td).compute_horizontal_speed()[1]-xdot_spear[i]
    theta_lb = 1*np.pi/180
    theta_ub = 15*np.pi/180
    result = root_scalar(f, bracket=(theta_lb,theta_ub))
    print(result)
    if result.converged:
        dx, xdot = slerp.compute_horizontal_speed()
        W = slerp.compute_positive_work()
        h_eq[i] = np.sum(W/(2*9.81))
        v_cot_eq[i] = h_cot_spear[i]*dx/h_eq[i]
# Out:
# C:\Users\Joseph Sullivan\AppData\Local\Temp\ipykernel_13396\1975031087.py:50: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   coeffs, res, rank, sigma = np.linalg.lstsq(A,b)
#       converged: True
#            flag: converged
#  function_calls: 8
#      iterations: 7
#            root: 0.03520201579297015
#          method: brentq
#       converged: True
#            flag: converged
#  function_calls: 9
#      iterations: 8
#            root: 0.04476910607696876
#          method: brentq
#       converged: True
#            flag: converged
#  function_calls: 11
#      iterations: 10
#            root: 0.058591957032018034
#          method: brentq
#       converged: True
#            flag: converged
#  function_calls: 15
#      iterations: 14
#            root: 0.0788053433091545
#          method: brentq
#       converged: True
#            flag: converged
#  function_calls: 7
#      iterations: 6
#            root: 0.10409734495031663
#          method: brentq
#       converged: True
#            flag: converged
#  function_calls: 14
#      iterations: 13
#            root: 0.135569307817958
#          method: brentq
#       converged: True
#            flag: converged
#  function_calls: 15
#      iterations: 14
#            root: 0.17571204019481831
#          method: brentq
#       converged: True
#            flag: converged
#  function_calls: 14
#      iterations: 13
#            root: 0.20151833555170592
#          method: brentq

# %%
from matplotlib.gridspec import GridSpec
import matplotlib.ticker as mtick
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(4,8), sharex=True)


# first figure, reduction in cost of transport
C0 = without_hsa_conf['Electrical Loss']
C1 = hsa_conf['Electrical Loss']
E0 = (C0[0,:]+C0[1,:])/2
E1 = (C1[0,:]+C1[1,:])/2
Y = 1 - E1/E0
LB = 1-C1[1,:]/C0[0,:]
UB = 1-C1[0,:]/C0[1,:]

axs[0].plot(masses, Y, color='C3', marker='o', label=r'$\frac{E_1-E_0}{E_0}$')
axs[0].fill_between(masses, LB, UB, color='C3', alpha=.2, label='99% CI')
# axs[0].yaxis.set_major_formatter(mtick.PercentFormatter())
axs[0].xaxis.set_tick_params(labelbottom=True)
axs[0].legend()
axs[0].grid(visible=True)
axs[0].set_ylabel('Relative Change (%)',labelpad=2)
axs[0].set_title('(a) Relative Reduction in Electrical Cost')


# second figure is change in TCOT and MCOT

C0 = without_hsa_conf['Motor Work']
C1 = hsa_conf['Motor Work']
W0 = (C0[0,:]+C0[1,:])/2
W1 = (C1[0,:]+C1[1,:])/2
Y = W1-W0
print(Y)
axs[1].plot(masses, Y-.01, label=r'$ΔW$ Motor Work', marker=6, color='C5')


C0 = without_hsa_conf['Thermal Loss']
C1 = hsa_conf['Thermal Loss']
T0 = (C0[0,:]+C0[1,:])/2
T1 = (C1[0,:]+C1[1,:])/2
Y = T1-T0
print(Y)
axs[1].plot(masses, Y+.01, label=r'$ΔT$ Thermal Loss', marker=7, color='C2')

axs[1].set_ylabel(r'$Δ \,$ Joules',labelpad=0)
axs[1].set_title('(c) Breakdown of Work and Thermal Loss Changes')
axs[1].set_ylim(-1.75, .5)
axs[1].grid(visible=True)
axs[1].legend(loc=(.5, .4))
axs[1].set_xticks(ticks=masses)


C = hsa_conf['COT']
Y = (C[0,:]+C[1,:])/2
hop_avg = summary_df_filt.loc[summary_df_filt['HSA']==True, 'Hop Height'].mean()
axs[2].plot(masses, Y, color='C1', marker='d', label='with HSA')
axs[2].fill_between(masses, C[0,:], C[1,:], alpha=.25, color='C1')

C = without_hsa_conf['COT']
Y = (C[0,:]+C[1,:])/2
hop_avg = summary_df_filt.loc[summary_df_filt['HSA']==True, 'Hop Height'].mean()
axs[2].plot(masses, Y, color='C0', marker='s', label=rf'without HSA')
axs[2].fill_between(masses, C[0,:], C[1,:], alpha=.25, color='C0')

imin = np.argmin(v_cot_eq)
axs[2].axhline(y=v_cot_eq[imin],color='black', linestyle='-.')
axs[2].annotate(f'SPEAR, {100*h_eq[imin]:.1f} cm hop height', [1.3,v_cot_eq[imin]+.05], color='black')
imax = np.argmax(v_cot_eq)
axs[2].axhline(y=v_cot_eq[imax],color='C5', linestyle='-.')
axs[2].annotate(f'SPEAR, {100*h_eq[imax]:.1f} cm hop height', [1.3,v_cot_eq[imax]-.15], color='C5')
# axs[2].axhline(y=2.9,color='black', linestyle='-.')
# axs[2].annotate(f'SPEAR, 11 cm hop height', [1.3,2.9-.15], color='black')
axs[2].set_title('(b) Hopping Cost of Transport')
axs[2].xaxis.set_tick_params(labelbottom=True)
axs[2].grid(visible=True)
axs[2].legend(loc=(.6,.35))
axs[2].set_ylim(2.5, 4.5)
axs[2].set_xlabel('Total Mass (kg)')


fig.suptitle('HSA Reduces Electrical Cost of Hopping')
fig.tight_layout()
fig.savefig('hopping_results.png', dpi=1200)
# Out:
# [0.34221252 0.31435306 0.21796521 0.32769002]
# [-0.98013754 -1.13109771 -1.40603907 -1.6475561 ]

# %%
# Relative Change, by itself
fig, axs = plt.subplots(figsize=(5,4))

# first figure, reduction in cost of transport
C0 = without_hsa_conf['Electrical Loss']
C1 = hsa_conf['Electrical Loss']
E0 = (C0[0,:]+C0[1,:])/2
E1 = (C1[0,:]+C1[1,:])/2
Y = 1 - E1/E0
LB = 1-C1[1,:]/C0[0,:]
UB = 1-C1[0,:]/C0[1,:]

axs.plot(masses, Y, color='C3', marker='o', label=r'$\frac{E_\text{HSA}-E_\text{no HSA}}{E_\text{no HSA}}$')
axs.fill_between(masses, LB, UB, color='C3', alpha=.2, label='99% CI')
axs.xaxis.set_tick_params(labelbottom=True)
axs.legend()
axs.grid(visible=True)
axs.set_ylabel('Relative Change (%)',labelpad=2)
axs.set_title('Relative Reduction in Electrical Cost')
axs.set_xlabel('Total Mass (kg)')
fig.savefig('cost_reduction.png',dpi=900)

# %%
# Thermal stuff
fig, axs = plt.subplots(figsize=(5,4))

C0 = without_hsa_conf['Motor Work']
C1 = hsa_conf['Motor Work']
W0 = (C0[0,:]+C0[1,:])/2
W1 = (C1[0,:]+C1[1,:])/2
Y = W1-W0
print(Y)
axs.plot(masses, Y-.01, label=r'$ΔW$ Motor Work', marker=6, color='C5')

C0 = without_hsa_conf['Thermal Loss']
C1 = hsa_conf['Thermal Loss']
T0 = (C0[0,:]+C0[1,:])/2
T1 = (C1[0,:]+C1[1,:])/2
Y = T1-T0
print(Y)
axs.plot(masses, Y+.01, label=r'$ΔT$ Thermal Loss', marker=7, color='C2')

axs.set_ylabel(r'$Δ \,$ Joules',labelpad=0)
axs.set_title('Breakdown of Work and Thermal Loss Changes')
axs.set_ylim(-1.75, .5)
axs.grid(visible=True)
axs.legend(loc=(.5, .4))
axs.set_xticks(ticks=masses)
axs.set_xlabel('Total Mass (kg)')
fig.savefig('work_vs_joule.png',dpi=900)
# Out:
# [0.34221252 0.31435306 0.21796521 0.32769002]
# [-0.98013754 -1.13109771 -1.40603907 -1.6475561 ]

# %%
fig, axs = plt.subplots(figsize=(5,4))
C = hsa_conf['COT']
Y = (C[0,:]+C[1,:])/2
hop_avg = summary_df_filt.loc[summary_df_filt['HSA']==True, 'Hop Height'].mean()
axs.plot(masses, Y, color='C1', marker='d', label='with HSA')
axs.fill_between(masses, C[0,:], C[1,:], alpha=.25, color='C1')

C = without_hsa_conf['COT']
Y = (C[0,:]+C[1,:])/2
hop_avg = summary_df_filt.loc[summary_df_filt['HSA']==True, 'Hop Height'].mean()
axs.plot(masses, Y, color='C0', marker='s', label=rf'without HSA')
axs.fill_between(masses, C[0,:], C[1,:], alpha=.25, color='C0')

imin = np.argmin(v_cot_eq)
axs.axhline(y=v_cot_eq[imin],color='black', linestyle='-.')
axs.annotate(f'SPEAR, {100*h_eq[imin]:.1f} cm hop height', [1.3,v_cot_eq[imin]+.05], color='black')
imax = np.argmax(v_cot_eq)
axs.axhline(y=v_cot_eq[imax],color='C5', linestyle='-.')
axs.annotate(f'SPEAR, {100*h_eq[imax]:.1f} cm hop height', [1.3,v_cot_eq[imax]-.15], color='C5')
# axs[2].axhline(y=2.9,color='black', linestyle='-.')
# axs[2].annotate(f'SPEAR, 11 cm hop height', [1.3,2.9-.15], color='black')
axs.set_title('Hopping Cost of Transport')
axs.xaxis.set_tick_params(labelbottom=True)
axs.grid(visible=True)
axs.legend(loc=(.6,.4))
axs.set_ylim(2.5, 4.5)
axs.set_xlabel('Total Mass (kg)')

fig.savefig('cost_of_transport.png', dpi=900)

# %%
frame = summary_df_filt['HSA'] == True
hop_avg = summary_df_filt.loc[frame, 'Hop Height'].mean()
hop_std = summary_df_filt.loc[frame, 'Hop Height'].std()
print(f'HSA Hop Height mean: {hop_avg}, Std: {hop_std}')
plt.hist(summary_df_filt.loc[frame, 'Hop Height'])
frame = summary_df_filt['HSA'] == False
hop_avg = summary_df_filt.loc[frame, 'Hop Height'].mean()
hop_std = summary_df_filt.loc[frame, 'Hop Height'].std()
print(f'Without HSA Hop Height mean: {hop_avg}, Std: {hop_std}')
plt.hist(summary_df_filt.loc[frame, 'Hop Height'], alpha = .5)
# Out:
# HSA Hop Height mean: 0.051433417864496345, Std: 0.0011682090789059572
# Without HSA Hop Height mean: 0.050991284986417, Std: 0.0016899315732376036
# (array([ 7.,  8., 16., 32., 39., 37., 35., 55., 28., 16.]),
#  array([0.04654424, 0.04731366, 0.04808309, 0.04885251, 0.04962194,
#         0.05039136, 0.05116078, 0.05193021, 0.05269963, 0.05346906,
#         0.05423848]),
#  <BarContainer object of 10 artists>)

# %%
print((100*summary_df_filt['Hop Height']).mean())
print((100*summary_df_filt['Hop Height']).std()**2)
# Out:
# 5.122422847850733
# 0.021153141927453982

# %%
hsa_frame = summary_df_filt['HSA'] == True
without_frame = summary_df_filt['HSA'] == False

for mass in summary_df_filt['Mass'].unique():
    mass_frame = summary_df_filt['Mass'] == mass
    stat = summary_df_filt.loc[mass_frame & hsa_frame, 'Negative Motor Work'].mean() / summary_df_filt.loc[mass_frame&without_frame,'Negative Motor Work'].mean()
    print(f'Mass = {mass}')
    hsa_hops = sum(mass_frame & hsa_frame)
    without_hops = sum(mass_frame & without_frame)
    print(f'Number of hops: {(hsa_hops, without_hops)}')
    print(f'Average reduction in negative motor work: {1-stat:.1f}')
# Out:
# Mass = 1.3
# Number of hops: (77, 72)
# Average reduction in negative motor work: 0.8
# Mass = 1.5
# Number of hops: (73, 69)
# Average reduction in negative motor work: 0.8
# Mass = 1.7
# Number of hops: (78, 66)
# Average reduction in negative motor work: 0.8
# Mass = 1.9
# Number of hops: (76, 66)
# Average reduction in negative motor work: 0.8

# %%
# need to get all the controller parameters ready for a table

control_params = {
'Mass' : [],
'HSA' : [],
'Kf' : [],
'bf' : [],
'Ks' : [],
'bs' : [],
'u min' : [],
'u max' : [],
}
for cond, trials in conditions.items():
    HSA = 'no_hsa' not in cond
    mass = trials[0]['experiment_config']['mass']/1000
    Kf = trials[0]['experiment_config']['controller']['kp'][1]
    bf = trials[0]['experiment_config']['controller']['kd'][1]
    Ks = trials[0]['experiment_config']['controller']['kp'][3]
    bs = trials[0]['experiment_config']['controller']['kd'][3]
    u = [trial['experiment_config']['controller']['u_ff'] for trial in trials]
    control_params['Mass'].append(mass)
    control_params['HSA'].append(HSA)
    control_params['Kf'].append(Kf)
    control_params['bf'].append(bf)
    control_params['Ks'].append(Ks)
    control_params['bs'].append(bs)
    control_params['u min'].append(min(u))
    control_params['u max'].append(max(u))

control_param_df = pd.DataFrame(control_params)

# %%
# print(control_param_df.to_latex())
latex_str = control_param_df.to_latex(float_format = "%.2f", formatters={'HSA' : lambda b: 'with HSA' if b else 'without HSA' })
print(latex_str)
# Out:
# \begin{tabular}{lrrrrrrll}
# \toprule
#  & Mass & HSA & Kf & bf & Ks & bs & u min & u max \\
# \midrule
# 0 & 1.30 & with HSA & 0.00 & 0.07 & 0.00 & 0.00 & [0.0, 0.0, 0.0, -2.75] & [0.0, 0.0, 0.0, -2.75] \\
# 1 & 1.50 & with HSA & 0.00 & 0.07 & 0.00 & 0.00 & [0.0, 0.0, 0.0, -2.85] & [0.0, 0.0, 0.0, -2.85] \\
# 2 & 1.70 & with HSA & 0.00 & 0.07 & 0.00 & 0.00 & [0.0, 0.0, 0.0, -3.25] & [0.0, 0.0, 0.0, -3.25] \\
# 3 & 1.90 & with HSA & 0.00 & 0.07 & 0.00 & 0.00 & [0.0, 0.0, 0.0, -3.25] & [0.0, 0.0, 0.0, -3.25] \\
# 4 & 1.30 & without HSA & 2.70 & 0.10 & 2.70 & 0.10 & [0.0, 0.0, 0.0, -3.2] & [0.0, 0.0, 0.0, -3.2] \\
# 5 & 1.50 & without HSA & 2.70 & 0.10 & 2.70 & 0.10 & [0.0, 0.0, 0.0, -3.1] & [0.0, 0.0, 0.0, -3.1] \\
# 6 & 1.70 & without HSA & 2.70 & 0.10 & 2.70 & 0.10 & [0.0, 0.0, 0.0, -3.1] & [0.0, 0.0, 0.0, -3.1] \\
# 7 & 1.90 & without HSA & 2.70 & 0.10 & 2.70 & 0.10 & [0.0, 0.0, 0.0, -3.1] & [0.0, 0.0, 0.0, -3.1] \\
# \bottomrule
# \end{tabular}
