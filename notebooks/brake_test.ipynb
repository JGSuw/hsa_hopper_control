# %%
import numpy as np
import yaml
import os

directory = '/home/joseph/workspaces/hsa_hopper/hsa_hopper_control/data/brake_test'
exp_folders = os.listdir(directory)
experiment_configs = []
experiment_data = []
for subfolder in exp_folders:
    print(type(subfolder))
    experiment_directory = os.path.join((subfolder,directory))
    print(experiment_directory)
    with open(os.path.join('experiment_config.yaml',experiment_directory), 'r') as f:
        experiment_configs.append(yaml.load(f,yaml.Loader))
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       9 for subfolder in exp_folders:
#      10     print(type(subfolder))
# ---> 11     experiment_directory = os.path.join((subfolder,directory))
#      12     print(experiment_directory)
#      13     with open(os.path.join('experiment_config.yaml',experiment_directory), 'r') as f:
#
# File <frozen posixpath>:76, in join(a, *p)
#
# TypeError: expected str, bytes or os.PathLike object, not tuple
